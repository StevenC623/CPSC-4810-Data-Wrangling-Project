# %% [markdown]
# # CPSC4810 Data Wrangling Project
# #### Leo Liang
# #### Qirui Cao
# #### Latesh Subramanayam

# %% [markdown]
# # Project objectives and description
#
# ### Objectives of the Data Wrangling Project
#
# Employ all python techniques and skills learnt during the CPSC 4810 Course to :
#
#     1. Clean the multiple Data sets
#     2. Merge the datsets to generate a comprehensive master dataset
#     3. Conduct basic analysis and visualisation to identify and explore any relationships
#
# ### Objectives of Project
#
# We wish to conduct research into the US Covid pandemic data pertaining to:
#
#     1. Positive Cases
#     2. Vaccination rates
#     3. Death rates
#     4. Median Household Income
#     5. Poverty Rates
#
# Further we wish to explore if there is any relationship based on few generalized theories and we want to project time series county-level or state level cases/deaths onto US map, and showcase the trend of the COVID in US.

# %% [markdown]
# ## Data sources
#
# Description and Source of raw datsets
#
# 1. US_county
#
# link: https://www.kaggle.com/headsortails/covid19-us-county-jhu-data-demographics?select=covid_us_county.csv
#
# Dataset containing county wise coivd case and death records.
#
# 2. US_poverty estimates
#
# link: https://github.com/govex/COVID-19/blob/master/data_tables/Data_for_UScounty_map/PovertyEstimates.csv
#
# Dataset containing state/county wise poverty estimates in 2018.
#
# 3. US_county
#
# link: https://www.kaggle.com/headsortails/covid19-us-county-jhu-data-demographics?select=us_county.csv
#
# Dataset containing US's county wise population, gender, age information.
#
# 4. US_vaccination rates
#
# link: https://ourworldindata.org/us-states-vaccinations
#
# Dataset containing county wise coivd vaccination rate records.
#
# 5. US_StateLonLat
#
# link: https://github.com/jasperdebie/VisInfo/blob/master/us-state-capitals.csv
#
# Dataset containing state's capital longitude and Latitude records.

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

import matplotlib.colors as mcol
import matplotlib.cm as cm

import plotly.express as px

from PIL import Image

# %% [markdown]
# ## Section 1 Data Inspection and Cleaning
#
# In this section, we inspected each raw dataset for finding the key column to merge in later use. Also we looked at the missing values, and fount out the potential reason of missing (data lost/ recorded incorrectly /missing values by nature) for data removal or corrections.

# %% [markdown]
# ### Inspect the county data set

# %%
dfCounty = pd.read_csv("data/us_county.csv")

# %% [markdown]
# Data preview:

# %%
dfCounty.head(5)
# Out:
#    fips          county    state state_code    male  female  median_age  \
# 0  1001  Autauga County  Alabama         AL   26874   28326        37.8
# 1  1003  Baldwin County  Alabama         AL  101188  106919        42.8
# 2  1005  Barbour County  Alabama         AL   13697   12085        39.9
# 3  1007     Bibb County  Alabama         AL   12152   10375        39.9
# 4  1009   Blount County  Alabama         AL   28434   29211        40.8
#
#    population  female_percentage        lat       long
# 0       55200          51.315217  32.534923 -86.642730
# 1      208107          51.376936  30.727479 -87.722564
# 2       25782          46.873788  31.869581 -85.393210
# 3       22527          46.055844  32.998628 -87.126475
# 4       57645          50.673953  33.980869 -86.567380

# %%
print("County dataset has", dfCounty.shape[0], "rows and", dfCounty.shape[1], "columns in the dataset.")
# Out:
# County dataset has 3220 rows and 11 columns in the dataset.

# %%
print("The number of rows in the dataset is equal to the number of unique values in column 'fips':", 
      len(dfCounty) == dfCounty.fips.nunique())
# Out:
# The number of rows in the dataset is equal to the number of unique values in column 'fips': True

# %% [markdown]
# Since the number of rows of the dataframe is equal to the number of unique values for variable "fips". We can consider the column "fips" as the key of the dataframe. That is, each row in dataframe dfCounty represents a different US county.

# %%
dfCounty.isnull().sum()
# Out:
# fips                  0
# county                0
# state                 0
# state_code           79
# male                  0
# female                0
# median_age            0
# population            0
# female_percentage     0
# lat                   0
# long                  0
# dtype: int64

# %% [markdown]
# Then, by running the total number of missing values for each variable, we find out that there are 79 missing values for "state_code". Then we need to check those rows containing missing values.

# %%
dfCounty[dfCounty.state_code.isnull()]['state'].value_counts()
# Out:
# Puerto Rico             78
# District of Columbia     1
# Name: state, dtype: int64

# %%
print("Puerto Rico has", len(dfCounty[dfCounty.state == "Puerto Rico"]), "rows in the dataframe. ")
# Out:
# Puerto Rico has 78 rows in the dataframe.

# %%
print("District of Columbia", len(dfCounty[dfCounty.state == "District of Columbia"]), "rows in the dataframe")
# Out:
# District of Columbia 1 rows in the dataframe

# %% [markdown]
# We find out that the only two states which do not have a state code are Puerto Rico and District of Columbia. By comparing the number of rows for two states, and the number of missing value occurance, we can be sure that state Puerto Rico and District of Columbia do not have state code.
#
# This is because both areas are not a US state, then they do not have a US state code. Since Puerto Rico is not part of 50 states + 1 disctrict, we exclude those observations from the project.

# %%
dfCounty = dfCounty.drop(dfCounty[dfCounty.state == "Puerto Rico"].index)
print("The number of unique states in the dataframe: ", dfCounty.state.nunique())
dfCounty.state.unique()
# Out:
# The number of unique states in the dataframe:  51
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %% [markdown]
# Then, we aggregate the population by all states to replicate the raw dataframe with state-level information.

# %%
state_pop = pd.DataFrame(dfCounty.groupby('state')[['male','female','population']].sum())
state_pop["female_proportion"] = state_pop.female/state_pop.population
state_pop.reset_index(level=0, inplace=True)
state_pop.head()
# Out:
#         state      male    female  population  female_proportion
# 0     Alabama   2355799   2508881     4864680           0.515734
# 1      Alaska    385579    352937      738516           0.477900
# 2     Arizona   3453439   3493246     6946685           0.502865
# 3    Arkansas   1468412   1522259     2990671           0.509002
# 4  California  19453769  19694991    39148760           0.503081

# %% [markdown]
# ### Inspect the Poverty data

# %%
dfPoverty = pd.read_csv("data/PovertyEstimates_us_county.csv")

# %% [markdown]
# Data preview:

# %%
dfPoverty.head(5)
# Out:
#    FIPStxt Stabr       Area_name  Rural-urban_Continuum_Code_2003  \
# 0        0    US   United States                              NaN
# 1     1000    AL         Alabama                              NaN
# 2     1001    AL  Autauga County                              2.0
# 3     1003    AL  Baldwin County                              4.0
# 4     1005    AL  Barbour County                              6.0
#
#    Urban_Influence_Code_2003  Rural-urban_Continuum_Code_2013  \
# 0                        NaN                              NaN
# 1                        NaN                              NaN
# 2                        2.0                              2.0
# 3                        5.0                              3.0
# 4                        6.0                              6.0
#
#    Urban_Influence_Code_2013  POVALL_2018  CI90LBAll_2018  CI90UBALL_2018  \
# 0                        NaN     41852315        41619366        42085264
# 1                        NaN       801758          785668          817848
# 2                        2.0         7587            6334            8840
# 3                        2.0        21069           17390           24748
# 4                        6.0         6788            5662            7914
#
#    ...  CI90UB517P_2018  MEDHHINC_2018  CI90LBINC_2018  CI90UBINC_2018  \
# 0  ...             17.2          61937           61843           62031
# 1  ...             23.7          49881           49123           50639
# 2  ...             23.9          59338           53628           65048
# 3  ...             16.9          57588           54437           60739
# 4  ...             45.9          34382           31157           37607
#
#    POV04_2018  CI90LB04_2018  CI90UB04_2018  PCTPOV04_2018  CI90LB04P_2018  \
# 0   3758704.0      3714862.0      3802546.0           19.5            19.3
# 1     73915.0        69990.0        77840.0           26.0            24.6
# 2         NaN            NaN            NaN            NaN             NaN
# 3         NaN            NaN            NaN            NaN             NaN
# 4         NaN            NaN            NaN            NaN             NaN
#
#    CI90UB04P_2018
# 0            19.7
# 1            27.4
# 2             NaN
# 3             NaN
# 4             NaN
#
# [5 rows x 34 columns]

# %%
dfPoverty.columns
# Out:
# Index(['FIPStxt', 'Stabr', 'Area_name', 'Rural-urban_Continuum_Code_2003',
#        'Urban_Influence_Code_2003', 'Rural-urban_Continuum_Code_2013',
#        'Urban_Influence_Code_2013', 'POVALL_2018', 'CI90LBAll_2018',
#        'CI90UBALL_2018', 'PCTPOVALL_2018', 'CI90LBALLP_2018',
#        'CI90UBALLP_2018', 'POV017_2018', 'CI90LB017_2018', 'CI90UB017_2018',
#        'PCTPOV017_2018', 'CI90LB017P_2018', 'CI90UB017P_2018', 'POV517_2018',
#        'CI90LB517_2018', 'CI90UB517_2018', 'PCTPOV517_2018', 'CI90LB517P_2018',
#        'CI90UB517P_2018', 'MEDHHINC_2018', 'CI90LBINC_2018', 'CI90UBINC_2018',
#        'POV04_2018', 'CI90LB04_2018', 'CI90UB04_2018', 'PCTPOV04_2018',
#        'CI90LB04P_2018', 'CI90UB04P_2018'],
#       dtype='object')

# %% [markdown]
# Then, we altered the dataset to keep the relevant columns.

# %%
dfPoverty = dfPoverty[['FIPStxt', 'Stabr', 'Area_name', 'Rural-urban_Continuum_Code_2013', 'Urban_Influence_Code_2013', 
                        'POVALL_2018', 'PCTPOVALL_2018', 'POV017_2018', 'PCTPOV017_2018', 'MEDHHINC_2018']]

# %%
print("Poverty dataset has", dfPoverty.shape[0], "rows and", dfPoverty.shape[1], "columns in the dataset.")
# Out:
# Poverty dataset has 3193 rows and 10 columns in the dataset.

# %%
print("The number of rows in the dataset is equal to the number of unique values in column 'fips':", 
      len(dfPoverty) == dfPoverty["FIPStxt"].nunique())
# Out:
# The number of rows in the dataset is equal to the number of unique values in column 'fips': True

# %% [markdown]
# Similarly, since the number of rows of the dataframe is equal to the number of unique values for variable "FIPStxt". We can consider the column "FIPStxt" as the key of the dataframe. That is, each row in dataframe dfCounty represents a different US area.

# %%
dfPoverty.isnull().sum()
# Out:
# FIPStxt                             0
# Stabr                               0
# Area_name                           0
# Rural-urban_Continuum_Code_2013    52
# Urban_Influence_Code_2013          52
# POVALL_2018                         0
# PCTPOVALL_2018                      0
# POV017_2018                         0
# PCTPOV017_2018                      0
# MEDHHINC_2018                       0
# dtype: int64

# %% [markdown]
# Then, by running the total number of missing values for each variable, we find out that there are 52 missing values for 2013's "RUCC" and "UIC". Then we need to check those rows containing missing values.

# %%
dfPoverty[dfPoverty["Rural-urban_Continuum_Code_2013"].isna()]["Area_name"]
# Out:
# 0              United States
# 1                    Alabama
# 69                    Alaska
# 99                   Arizona
# 115                 Arkansas
# 191               California
# 250                 Colorado
# 315              Connecticut
# 324                 Delaware
# 328     District of Columbia
# 330                  Florida
# 398                  Georgia
# 558                   Hawaii
# 563                    Idaho
# 608                 Illinois
# 711                  Indiana
# 804                     Iowa
# 904                   Kansas
# 1010                Kentucky
# 1131               Louisiana
# 1196                   Maine
# 1213                Maryland
# 1238           Massachusetts
# 1253                Michigan
# 1337               Minnesota
# 1425             Mississippi
# 1508                Missouri
# 1624                 Montana
# 1681                Nebraska
# 1775                  Nevada
# 1793           New Hampshire
# 1804              New Jersey
# 1826              New Mexico
# 1860                New York
# 1923          North Carolina
# 2024            North Dakota
# 2078                    Ohio
# 2167                Oklahoma
# 2245                  Oregon
# 2282            Pennsylvania
# 2350            Rhode Island
# 2356          South Carolina
# 2403            South Dakota
# 2470               Tennessee
# 2566                   Texas
# 2821                    Utah
# 2851                 Vermont
# 2866                Virginia
# 3000              Washington
# 3040           West Virginia
# 3096               Wisconsin
# 3169                 Wyoming
# Name: Area_name, dtype: object

# %%
dfPoverty[dfPoverty["Urban_Influence_Code_2013"].isna()]["Area_name"]
# Out:
# 0              United States
# 1                    Alabama
# 69                    Alaska
# 99                   Arizona
# 115                 Arkansas
# 191               California
# 250                 Colorado
# 315              Connecticut
# 324                 Delaware
# 328     District of Columbia
# 330                  Florida
# 398                  Georgia
# 558                   Hawaii
# 563                    Idaho
# 608                 Illinois
# 711                  Indiana
# 804                     Iowa
# 904                   Kansas
# 1010                Kentucky
# 1131               Louisiana
# 1196                   Maine
# 1213                Maryland
# 1238           Massachusetts
# 1253                Michigan
# 1337               Minnesota
# 1425             Mississippi
# 1508                Missouri
# 1624                 Montana
# 1681                Nebraska
# 1775                  Nevada
# 1793           New Hampshire
# 1804              New Jersey
# 1826              New Mexico
# 1860                New York
# 1923          North Carolina
# 2024            North Dakota
# 2078                    Ohio
# 2167                Oklahoma
# 2245                  Oregon
# 2282            Pennsylvania
# 2350            Rhode Island
# 2356          South Carolina
# 2403            South Dakota
# 2470               Tennessee
# 2566                   Texas
# 2821                    Utah
# 2851                 Vermont
# 2866                Virginia
# 3000              Washington
# 3040           West Virginia
# 3096               Wisconsin
# 3169                 Wyoming
# Name: Area_name, dtype: object

# %% [markdown]
# By observing the missing values in both columns, the corresponding area names are states and US itself. The missing values are due to the fact that the country US itself and states are not applied to the county-level code, as it only applies to counties.

# %% [markdown]
# Meanwhile, Rural-urban Continuum Code 2013 and Urban Influence Code 2013 are all categorical variables, which have their corresponding categories. (Please see documents below) Then, we need to map the code to their corresponding description.
#
# Rural-Urban Continuum Code: https://www.ers.usda.gov/data-products/rural-urban-continuum-codes/documentation/
# Urban Influence Code: https://www.ers.usda.gov/data-products/urban-influence-codes/documentation.aspx.

# %%
im1 = Image.open("data/RUCC.png") 
im1
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=837x421 at 0x2EA3C1CE220>

# %%
im2 = Image.open("data/UIC.png") 
im2
# Out:
# <PIL.PngImagePlugin.PngImageFile image mode=RGBA size=838x740 at 0x2EA3C28AE20>

# %% [markdown]
# For simiplicity, we rename the values for both codes into levels for better visualization in the later part.

# %%
RUCC = {1: "Level 1", 
           2: "Level 2",
           3: "Level 3",
           4: "Level 4",
           5: "Level 5",
           6: "Level 6", 
           7: "Level 7", 
           8: "Level 8",
           9: "Level 9"
          }

UIC = {1: "Level 1",
       2: "Level 2",
       3: "Level 3",
       4: "Level 4",
       5: "Level 5",
       6: "Level 6",
       7: "Level 7",
       8: "Level 8",
       9: "Level 9",
       10: "Level 10",
       11: "Level 11",
       12: "Level 12",
       }

dfPoverty["Rural-urban_Continuum_Code_2013"] = dfPoverty["Rural-urban_Continuum_Code_2013"].map(RUCC)
dfPoverty["Urban_Influence_Code_2013"] = dfPoverty["Urban_Influence_Code_2013"].map(UIC)

# %% [markdown]
# Data preview:

# %%
dfPoverty.head(5)
# Out:
#    FIPStxt Stabr       Area_name Rural-urban_Continuum_Code_2013  \
# 0        0    US   United States                             NaN
# 1     1000    AL         Alabama                             NaN
# 2     1001    AL  Autauga County                         Level 2
# 3     1003    AL  Baldwin County                         Level 3
# 4     1005    AL  Barbour County                         Level 6
#
#   Urban_Influence_Code_2013  POVALL_2018  PCTPOVALL_2018  POV017_2018  \
# 0                       NaN     41852315            13.1     12997532
# 1                       NaN       801758            16.8       255613
# 2                   Level 2         7587            13.8         2509
# 3                   Level 2        21069             9.8         6442
# 4                   Level 6         6788            30.9         2242
#
#    PCTPOV017_2018  MEDHHINC_2018
# 0            18.0          61937
# 1            23.9          49881
# 2            19.3          59338
# 3            13.9          57588
# 4            43.9          34382

# %%
dfPoverty.describe()
# Out:
#             FIPStxt   POVALL_2018  PCTPOVALL_2018   POV017_2018  \
# count   3193.000000  3.193000e+03     3193.000000  3.193000e+03
# mean   30356.223301  3.932257e+04       15.125274  1.221190e+04
# std    15178.992102  7.583740e+05        6.092508  2.358859e+05
# min        0.000000  5.000000e+00        2.600000  5.000000e+00
# 25%    18173.000000  1.621000e+03       10.800000  5.030000e+02
# 50%    29175.000000  3.876000e+03       14.100000  1.200000e+03
# 75%    45075.000000  9.874000e+03       18.300000  2.966000e+03
# max    56045.000000  4.185232e+07       54.000000  1.299753e+07
#
#        PCTPOV017_2018  MEDHHINC_2018
# count     3193.000000    3193.000000
# mean        21.045443   52944.895709
# std          8.862190   13878.755803
# min          2.500000   25385.000000
# 25%         14.500000   43783.000000
# 50%         20.100000   50748.000000
# 75%         26.200000   59020.000000
# max         68.300000  140382.000000

# %% [markdown]
# We see a huge dispersion of poverty (median income ranging from 25385 to 140382, poverty rate ranging from 2.6% to 54%). It might be a potential candidate to be explored to relate with COVID cases/deaths.

# %% [markdown]
# ### Inspect COVID case and death data

# %%
dfcovCnty = pd.read_csv("data/covid_us_county.csv")

# %% [markdown]
# Data preview:

# %%
dfcovCnty.head(5)
# Out:
#      fips   county    state        lat       long        date  cases  \
# 0  1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-22      0
# 1  1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-23      0
# 2  1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-24      0
# 3  1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-25      0
# 4  1001.0  Autauga  Alabama  32.539527 -86.644082  2020-01-26      0
#
#   state_code  deaths
# 0         AL       0
# 1         AL       0
# 2         AL       0
# 3         AL       0
# 4         AL       0

# %%
print("COVID dataset has", dfcovCnty.shape[0], "rows and", dfcovCnty.shape[1], "columns in the dataset.")
# Out:
# COVID dataset has 1858152 rows and 9 columns in the dataset.

# %% [markdown]
# This data contains the county-level cumulative cases and deaths starting from January 22nd, 2020. Let's take the current date, and inspect the missing values

# %%
dfcovCnty_current = dfcovCnty[dfcovCnty['date'] == '2021-07-30']
dfcovCnty_current.head()
# Out:
#         fips   county    state        lat       long        date  cases  \
# 555   1001.0  Autauga  Alabama  32.539527 -86.644082  2021-07-30   7479
# 1111  1003.0  Baldwin  Alabama  30.727750 -87.722071  2021-07-30  24499
# 1667  1005.0  Barbour  Alabama  31.868263 -85.387129  2021-07-30   2462
# 2223  1007.0     Bibb  Alabama  32.996421 -87.125115  2021-07-30   2845
# 2779  1009.0   Blount  Alabama  33.982109 -86.567906  2021-07-30   7266
#
#      state_code  deaths
# 555          AL     114
# 1111         AL     328
# 1667         AL      61
# 2223         AL      65
# 2779         AL     139

# %%
print("current date COVID dataset has", dfcovCnty_current.shape[0], "rows and", dfcovCnty_current.shape[1], "columns in the dataset.")
# Out:
# current date COVID dataset has 3342 rows and 9 columns in the dataset.

# %%
dfcovCnty_current.isnull().sum()
# Out:
# fips          10
# county         6
# state          0
# lat            0
# long           0
# date           0
# cases          0
# state_code    89
# deaths         0
# dtype: int64

# %% [markdown]
# There are 10 missing values in column "fips", 6 in column "county" and 89 in column "state_code". We need to check all the rows containing these missing values.

# %%
dfcovCnty_current[dfcovCnty_current.fips.isnull()]
# Out:
#          fips                                     county          state  \
# 706119    NaN                        Dukes and Nantucket  Massachusetts
# 726691    NaN     Federal Correctional Institution (FCI)       Michigan
# 744483    NaN  Michigan Department of Corrections (MDOC)       Michigan
# 886263    NaN                                Kansas City       Missouri
# 1644091   NaN                                 Bear River           Utah
# 1646871   NaN                               Central Utah           Utah
# 1657435   NaN                             Southeast Utah           Utah
# 1657991   NaN                             Southwest Utah           Utah
# 1659659   NaN                                  TriCounty           Utah
# 1664107   NaN                               Weber-Morgan           Utah
#
#                lat        long        date  cases state_code  deaths
# 706119   41.406747  -70.687635  2021-07-30   3009         MA       6
# 726691    0.000000    0.000000  2021-07-30    320         MI       5
# 744483    0.000000    0.000000  2021-07-30  26770         MI     155
# 886263   39.099700  -94.578600  2021-07-30  49320         MO     617
# 1644091  41.521068 -113.083282  2021-07-30  23219         UT     114
# 1646871  39.372319 -111.575868  2021-07-30   9650         UT      72
# 1657435  38.996171 -110.701396  2021-07-30   3975         UT      31
# 1657991  37.854472 -111.441876  2021-07-30  31376         UT     289
# 1659659  40.124915 -109.517442  2021-07-30   5053         UT      42
# 1664107  41.271160 -111.914512  2021-07-30  33602         UT     233

# %% [markdown]
# Since in the merging stage of our project, we will merge by fips, which is the key column for most of our county-level dataframe, we will remove those rows containing missing values in fips.

# %%
dfcovCnty_current[dfcovCnty_current.county.isnull()]
# Out:
#             fips county                     state      lat      long  \
# 57267       60.0    NaN            American Samoa -14.2710 -170.1320
# 188483   88888.0    NaN          Diamond Princess   0.0000    0.0000
# 318587   99999.0    NaN            Grand Princess   0.0000    0.0000
# 319143      66.0    NaN                      Guam  13.4443  144.7937
# 1180943     69.0    NaN  Northern Mariana Islands  15.0979  145.6739
# 1673559     78.0    NaN            Virgin Islands  18.3358  -64.8963
#
#                date  cases state_code  deaths
# 57267    2021-07-30      0        NaN       0
# 188483   2021-07-30     49        NaN       0
# 318587   2021-07-30    103        NaN       3
# 319143   2021-07-30   8541        NaN     143
# 1180943  2021-07-30    183        NaN       2
# 1673559  2021-07-30   4606        NaN      37

# %% [markdown]
# Since the missing values in county indicates two cruise ships and four areas outside 50 states + 1 district, we remove those rows as well.

# %%
dfcovCnty=dfcovCnty.dropna(subset=['fips','county'])
dfcovCnty_current=dfcovCnty_current.dropna(subset=['fips','county'])

# %% [markdown]
# Then, we checked the rows with missing state codes, and found out that only Puerto Rico and District of Columbia don't have state code. It is the same case as the previous situation where both areas are not a US state, thus there are no state codes. And we removed rows with Puerto Rico as well.

# %%
dfcovCnty_current[dfcovCnty_current.state_code.isnull()].state.value_counts()
# Out:
# Puerto Rico             80
# District of Columbia     3
# Name: state, dtype: int64

# %%
print("Puerto Rico has", len(dfcovCnty_current[dfcovCnty_current.state == "Puerto Rico"]), "rows in the dataframe. ")
# Out:
# Puerto Rico has 80 rows in the dataframe.

# %%
print("District of Columbia", len(dfcovCnty_current[dfcovCnty_current.state == "District of Columbia"]), "rows in the dataframe")
# Out:
# District of Columbia 3 rows in the dataframe

# %%
dfcovCnty = dfcovCnty.drop(dfcovCnty[dfcovCnty.state == "Puerto Rico"].index)
dfcovCnty_current = dfcovCnty[dfcovCnty.date == '2021-07-30']
print("The number of unique states in the original dataset is:", dfcovCnty.state.nunique())
dfcovCnty.state.unique()
# Out:
# The number of unique states in the original dataset is: 51
# array(['Alabama', 'Alaska', 'Arizona', 'Arkansas', 'California',
#        'Colorado', 'Connecticut', 'Delaware', 'District of Columbia',
#        'Florida', 'Georgia', 'Hawaii', 'Idaho', 'Illinois', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Louisiana', 'Maine', 'Maryland',
#        'Massachusetts', 'Michigan', 'Minnesota', 'Mississippi',
#        'Missouri', 'Montana', 'Nebraska', 'Nevada', 'New Hampshire',
#        'New Jersey', 'New Mexico', 'New York', 'North Carolina',
#        'North Dakota', 'Ohio', 'Oklahoma', 'Oregon', 'Pennsylvania',
#        'Rhode Island', 'South Carolina', 'South Dakota', 'Tennessee',
#        'Texas', 'Utah', 'Vermont', 'Virginia', 'Washington',
#        'West Virginia', 'Wisconsin', 'Wyoming'], dtype=object)

# %%
dfcovCnty.isnull().sum()
# Out:
# fips             0
# county           0
# state            0
# lat              0
# long             0
# date             0
# cases            0
# state_code    1668
# deaths           0
# dtype: int64

# %%
dfcovCnty[dfcovCnty.state_code.isnull()].state.value_counts()
# Out:
# District of Columbia    1668
# Name: state, dtype: int64

# %%
print("Now, the number of rows in the dataset is equal to the number of unique values in column 'fips':", 
      len(dfcovCnty_current) == dfcovCnty_current.fips.nunique())
# Out:
# Now, the number of rows in the dataset is equal to the number of unique values in column 'fips': True

# %% [markdown]
# Since the number of rows of the dataframe is equal to the number of unique values for variable "fips". We can consider the column "fips" as the key of the dataframe. That is, each row in dataframe current represents a different US county.

# %%
dfcovCnty_current.describe()
# Out:
#                fips          lat         long         cases        deaths
# count   3246.000000  3246.000000  3246.000000  3.246000e+03   3246.000000
# mean   32083.336106    37.260840   -89.428180  1.065934e+04    187.518792
# std    17742.211826     8.522405    20.596120  3.834142e+04    723.357640
# min     1001.000000     0.000000  -174.159600  0.000000e+00      0.000000
# 25%    19041.500000    34.263872   -98.062361  1.020000e+03     18.000000
# 50%    30046.000000    38.162993   -89.900575  2.568500e+03     49.000000
# 75%    47008.500000    41.685722   -82.841249  6.731750e+03    117.000000
# max    90056.000000    69.314792     0.000000  1.297087e+06  24691.000000

# %% [markdown]
# Similar to the county data, we also aggregated the cumulative cases and deaths by state level to replicate the dataframe.

# %%
dfcovSt = pd.DataFrame(dfcovCnty.groupby(["state", "date"])[["cases", "deaths"]].sum())
dfcovSt.reset_index(inplace=True)
dfcovSt.head()
# Out:
#      state        date  cases  deaths
# 0  Alabama  2020-01-22      0       0
# 1  Alabama  2020-01-23      0       0
# 2  Alabama  2020-01-24      0       0
# 3  Alabama  2020-01-25      0       0
# 4  Alabama  2020-01-26      0       0

# %%
dfcovSt_current = dfcovSt[dfcovSt.date == "2021-07-30"]
dfcovSt_current.head()
# Out:
#            state        date    cases  deaths
# 555      Alabama  2021-07-30   577463   11510
# 1111      Alaska  2021-07-30    75486     389
# 1667     Arizona  2021-07-30   925169   18224
# 2223    Arkansas  2021-07-30   385113    6123
# 2779  California  2021-07-30  3956303   64423

# %% [markdown]
# ### Inspect the Vaccination Data

# %%
dfvac = pd.read_csv("data/us_state_vaccinations.csv")

# %% [markdown]
# Data preview:

# %%
dfvac.head()
# Out:
#          date location  total_vaccinations  total_distributed  \
# 0  2021-01-12  Alabama             78134.0           377025.0
# 1  2021-01-13  Alabama             84040.0           378975.0
# 2  2021-01-14  Alabama             92300.0           435350.0
# 3  2021-01-15  Alabama            100567.0           444650.0
# 4  2021-01-16  Alabama                 NaN                NaN
#
#    people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0            70861.0                                 0.15
# 1            74792.0                                 0.19
# 2            80480.0                                  NaN
# 3            86956.0                                 0.28
# 4                NaN                                  NaN
#
#    total_vaccinations_per_hundred  people_fully_vaccinated  \
# 0                            1.59                   7270.0
# 1                            1.71                   9245.0
# 2                            1.88                      NaN
# 3                            2.05                  13488.0
# 4                             NaN                      NaN
#
#    people_vaccinated_per_hundred  distributed_per_hundred  \
# 0                           1.45                     7.69
# 1                           1.53                     7.73
# 2                           1.64                     8.88
# 3                           1.77                     9.07
# 4                            NaN                      NaN
#
#    daily_vaccinations_raw  daily_vaccinations  daily_vaccinations_per_million  \
# 0                     NaN                 NaN                             NaN
# 1                  5906.0              5906.0                          1205.0
# 2                  8260.0              7083.0                          1445.0
# 3                  8267.0              7478.0                          1525.0
# 4                  7557.0              7498.0                          1529.0
#
#    share_doses_used
# 0             0.207
# 1             0.222
# 2             0.212
# 3             0.226
# 4               NaN

# %%
print("Vaccine dataset has", dfvac.shape[0], "rows and", dfvac.shape[1], "columns in the dataset.")
# Out:
# Vaccine dataset has 13088 rows and 14 columns in the dataset.

# %% [markdown]
# Since the dataset contains the time series state level data of US vaccination, we subsetted the current date as an example to examine the data.

# %%
dfvac_current = dfvac[dfvac.date == '2021-07-30']
dfvac_current.head()
# Out:
#             date        location  total_vaccinations  total_distributed  \
# 199   2021-07-30         Alabama           3586810.0          5092510.0
# 400   2021-07-30          Alaska            696377.0           853805.0
# 601   2021-07-30  American Samoa             51670.0            55830.0
# 802   2021-07-30         Arizona           7085856.0          8540830.0
# 1003  2021-07-30        Arkansas           2432736.0          3004150.0
#
#       people_vaccinated  people_fully_vaccinated_per_hundred  \
# 199           2116551.0                                34.33
# 400            376154.0                                45.48
# 601             28768.0                                42.31
# 802           3853257.0                                45.19
# 1003          1405459.0                                36.29
#
#       total_vaccinations_per_hundred  people_fully_vaccinated  \
# 199                            73.15                1683367.0
# 400                            95.19                 332678.0
# 601                            92.78                  23560.0
# 802                            97.35                3289110.0
# 1003                           80.61                1095214.0
#
#       people_vaccinated_per_hundred  distributed_per_hundred  \
# 199                           43.17                   103.86
# 400                           51.42                   116.71
# 601                           51.66                   100.25
# 802                           52.94                   117.34
# 1003                          46.57                    99.55
#
#       daily_vaccinations_raw  daily_vaccinations  \
# 199                  28844.0             13131.0
# 400                   1214.0               837.0
# 601                      0.0               229.0
# 802                  17540.0             12063.0
# 1003                 10935.0              9842.0
#
#       daily_vaccinations_per_million  share_doses_used
# 199                           2678.0             0.704
# 400                           1144.0             0.816
# 601                           4112.0             0.925
# 802                           1657.0             0.830
# 1003                          3261.0             0.810

# %%
dfvac_current.isnull().sum()
# Out:
# date                                   0
# location                               0
# total_vaccinations                     0
# total_distributed                      1
# people_vaccinated                      1
# people_fully_vaccinated_per_hundred    4
# total_vaccinations_per_hundred         4
# people_fully_vaccinated                1
# people_vaccinated_per_hundred          4
# distributed_per_hundred                4
# daily_vaccinations_raw                 0
# daily_vaccinations                     0
# daily_vaccinations_per_million         4
# share_doses_used                       1
# dtype: int64

# %% [markdown]
# Looking at the unique locations, we will only be keeping the states and the capital city

# %%
dfvac_current.location.unique()
# Out:
# array(['Alabama', 'Alaska', 'American Samoa', 'Arizona', 'Arkansas',
#        'Bureau of Prisons', 'California', 'Colorado', 'Connecticut',
#        'Delaware', 'Dept of Defense', 'District of Columbia',
#        'Federated States of Micronesia', 'Florida', 'Georgia', 'Guam',
#        'Hawaii', 'Idaho', 'Illinois', 'Indian Health Svc', 'Indiana',
#        'Iowa', 'Kansas', 'Kentucky', 'Long Term Care', 'Louisiana',
#        'Maine', 'Marshall Islands', 'Maryland', 'Massachusetts',
#        'Michigan', 'Minnesota', 'Mississippi', 'Missouri', 'Montana',
#        'Nebraska', 'Nevada', 'New Hampshire', 'New Jersey', 'New Mexico',
#        'New York State', 'North Carolina', 'North Dakota',
#        'Northern Mariana Islands', 'Ohio', 'Oklahoma', 'Oregon',
#        'Pennsylvania', 'Puerto Rico', 'Republic of Palau', 'Rhode Island',
#        'South Carolina', 'South Dakota', 'Tennessee', 'Texas',
#        'United States', 'Utah', 'Vermont', 'Veterans Health',
#        'Virgin Islands', 'Virginia', 'Washington', 'West Virginia',
#        'Wisconsin', 'Wyoming'], dtype=object)

# %% [markdown]
# Only location where it is a state will be kept, and also we need to change New York State to New York in order to match with other datasets.

# %%
dfvac_current = dfvac_current[~dfvac_current.location.isin(['American Samoa','Bureau of Prisons','Dept of Defense','Federated States of Micronesia',
               'Indian Health Svc','Long Term Care','Marshall Islands','Northern Mariana Islands',
               'Puerto Rico', 'Republic of Palau','United States','Veterans Health','Guam','Virgin Islands'])]
dfvac_current.location[dfvac_current.location == "New York State"] = "New York"
dfvac_current.location.nunique()
# Out:
# 51

# %% [markdown]
# Similarly, we removed those locations from the time series dataframe as well, and we have 51 unique locations.

# %%
dfvac = dfvac[~dfvac.location.isin(['American Samoa','Bureau of Prisons','Dept of Defense','Federated States of Micronesia',
               'Indian Health Svc','Long Term Care','Marshall Islands','Northern Mariana Islands',
               'Puerto Rico', 'Republic of Palau','United States','Veterans Health','Guam','Virgin Islands'])]
dfvac.location[dfvac.location == "New York State"] = "New York"
dfvac.location.nunique()
# Out:
# 51

# %% [markdown]
# checking for missing values again. We do not have missing values anymore.

# %%
dfvac_current.isnull().sum()
# Out:
# date                                   0
# location                               0
# total_vaccinations                     0
# total_distributed                      0
# people_vaccinated                      0
# people_fully_vaccinated_per_hundred    0
# total_vaccinations_per_hundred         0
# people_fully_vaccinated                0
# people_vaccinated_per_hundred          0
# distributed_per_hundred                0
# daily_vaccinations_raw                 0
# daily_vaccinations                     0
# daily_vaccinations_per_million         0
# share_doses_used                       0
# dtype: int64

# %% [markdown]
# now we have the 50 states and the capital city in the data

# %%
print("Now, the number of rows in the dataset is equal to the number of unique values in column 'location':", 
      len(dfvac_current) == dfvac_current.location.nunique())
# Out:
# Now, the number of rows in the dataset is equal to the number of unique values in column 'location': True

# %% [markdown]
# Since the number of rows of the dataframe is equal to the number of unique values for variable "location". We can consider the column "location" as the key column of the dataframe. That is, each row in dataframe current represents a different US county.

# %%
dfvac = dfvac[['date', 'location', 'people_vaccinated', 'people_fully_vaccinated_per_hundred',
       'total_vaccinations_per_hundred', 'people_fully_vaccinated',
       'people_vaccinated_per_hundred', 'daily_vaccinations',
       'daily_vaccinations_per_million']]

# %%
dfvac_current = dfvac_current[['date', 'location', 'people_vaccinated', 'people_fully_vaccinated_per_hundred',
       'total_vaccinations_per_hundred', 'people_fully_vaccinated',
       'people_vaccinated_per_hundred', 'daily_vaccinations',
       'daily_vaccinations_per_million']]

# %% [markdown]
# Then, we included the relevant columns for merging and visualizing.

# %% [markdown]
# ## Section 2 Merge county-level data

# %% [markdown]
# #### Merge the current county-level data
# Merge County info with covid cases by county (current only)

# %%
mergeCounty = pd.merge(dfCounty, dfcovCnty_current, how='inner', on='fips', validate = "1:1")
mergeCounty.head(5)
# Out:
#    fips        county_x  state_x state_code_x    male  female  median_age  \
# 0  1001  Autauga County  Alabama           AL   26874   28326        37.8
# 1  1003  Baldwin County  Alabama           AL  101188  106919        42.8
# 2  1005  Barbour County  Alabama           AL   13697   12085        39.9
# 3  1007     Bibb County  Alabama           AL   12152   10375        39.9
# 4  1009   Blount County  Alabama           AL   28434   29211        40.8
#
#    population  female_percentage      lat_x     long_x county_y  state_y  \
# 0       55200          51.315217  32.534923 -86.642730  Autauga  Alabama
# 1      208107          51.376936  30.727479 -87.722564  Baldwin  Alabama
# 2       25782          46.873788  31.869581 -85.393210  Barbour  Alabama
# 3       22527          46.055844  32.998628 -87.126475     Bibb  Alabama
# 4       57645          50.673953  33.980869 -86.567380   Blount  Alabama
#
#        lat_y     long_y        date  cases state_code_y  deaths
# 0  32.539527 -86.644082  2021-07-30   7479           AL     114
# 1  30.727750 -87.722071  2021-07-30  24499           AL     328
# 2  31.868263 -85.387129  2021-07-30   2462           AL      61
# 3  32.996421 -87.125115  2021-07-30   2845           AL      65
# 4  33.982109 -86.567906  2021-07-30   7266           AL     139

# %% [markdown]
# Merge the above with poverty data

# %%
mergeCouPov = pd.merge(mergeCounty, dfPoverty, how='inner', left_on='fips', right_on='FIPStxt', validate = "1:1")
mergeCouPov.head(5)
# Out:
#    fips        county_x  state_x state_code_x    male  female  median_age  \
# 0  1001  Autauga County  Alabama           AL   26874   28326        37.8
# 1  1003  Baldwin County  Alabama           AL  101188  106919        42.8
# 2  1005  Barbour County  Alabama           AL   13697   12085        39.9
# 3  1007     Bibb County  Alabama           AL   12152   10375        39.9
# 4  1009   Blount County  Alabama           AL   28434   29211        40.8
#
#    population  female_percentage      lat_x  ...  FIPStxt Stabr  \
# 0       55200          51.315217  32.534923  ...     1001    AL
# 1      208107          51.376936  30.727479  ...     1003    AL
# 2       25782          46.873788  31.869581  ...     1005    AL
# 3       22527          46.055844  32.998628  ...     1007    AL
# 4       57645          50.673953  33.980869  ...     1009    AL
#
#         Area_name  Rural-urban_Continuum_Code_2013  Urban_Influence_Code_2013  \
# 0  Autauga County                          Level 2                    Level 2
# 1  Baldwin County                          Level 3                    Level 2
# 2  Barbour County                          Level 6                    Level 6
# 3     Bibb County                          Level 1                    Level 1
# 4   Blount County                          Level 1                    Level 1
#
#   POVALL_2018  PCTPOVALL_2018 POV017_2018  PCTPOV017_2018  MEDHHINC_2018
# 0        7587            13.8        2509            19.3          59338
# 1       21069             9.8        6442            13.9          57588
# 2        6788            30.9        2242            43.9          34382
# 3        4400            21.8        1238            27.8          46064
# 4        7527            13.2        2374            18.0          50412
#
# [5 rows x 29 columns]

# %%
mergeCouPov.isnull().sum()
# Out:
# fips                               0
# county_x                           0
# state_x                            0
# state_code_x                       1
# male                               0
# female                             0
# median_age                         0
# population                         0
# female_percentage                  0
# lat_x                              0
# long_x                             0
# county_y                           0
# state_y                            0
# lat_y                              0
# long_y                             0
# date                               0
# cases                              0
# state_code_y                       1
# deaths                             0
# FIPStxt                            0
# Stabr                              0
# Area_name                          0
# Rural-urban_Continuum_Code_2013    0
# Urban_Influence_Code_2013          0
# POVALL_2018                        0
# PCTPOVALL_2018                     0
# POV017_2018                        0
# PCTPOV017_2018                     0
# MEDHHINC_2018                      0
# dtype: int64

# %% [markdown]
# Then we checked the missing values and found out that the missing values occur due to the fact that District of Columbia does not have a state code. And we keep District of Columbia, as it is one of the 50 states + 1 district.

# %%
mergeCouPov[mergeCouPov.state_code_x.isnull()]
# Out:
#       fips              county_x               state_x state_code_x    male  \
# 319  11001  District of Columbia  District of Columbia          NaN  324881
#
#      female  median_age  population  female_percentage      lat_x  ...  \
# 319  359617        33.9      684498          52.537334  38.904734  ...
#
#      FIPStxt Stabr             Area_name  Rural-urban_Continuum_Code_2013  \
# 319    11001    DC  District of Columbia                          Level 1
#
#      Urban_Influence_Code_2013 POVALL_2018  PCTPOVALL_2018 POV017_2018  \
# 319                    Level 1      107806            16.1       30803
#
#      PCTPOV017_2018  MEDHHINC_2018
# 319            24.5          82533
#
# [1 rows x 29 columns]

# %%
mergeCouPov[mergeCouPov.state_code_y.isnull()]
# Out:
#       fips              county_x               state_x state_code_x    male  \
# 319  11001  District of Columbia  District of Columbia          NaN  324881
#
#      female  median_age  population  female_percentage      lat_x  ...  \
# 319  359617        33.9      684498          52.537334  38.904734  ...
#
#      FIPStxt Stabr             Area_name  Rural-urban_Continuum_Code_2013  \
# 319    11001    DC  District of Columbia                          Level 1
#
#      Urban_Influence_Code_2013 POVALL_2018  PCTPOVALL_2018 POV017_2018  \
# 319                    Level 1      107806            16.1       30803
#
#      PCTPOV017_2018  MEDHHINC_2018
# 319            24.5          82533
#
# [1 rows x 29 columns]

# %% [markdown]
# Then, we removed some of the redundant columns and kept the rest.

# %%
county_current = mergeCouPov[['fips', 'county_x', 'state_x', 'state_code_x', 'male', 'female',
       'median_age', 'population', 'female_percentage', 'lat_x', 'long_x', 'date', 'cases',
       'deaths', 'Rural-urban_Continuum_Code_2013', 'Urban_Influence_Code_2013',
       'POVALL_2018', 'PCTPOVALL_2018', 'POV017_2018', 'PCTPOV017_2018',
       'MEDHHINC_2018']]

# %%
county_current.head(5)
# Out:
#    fips        county_x  state_x state_code_x    male  female  median_age  \
# 0  1001  Autauga County  Alabama           AL   26874   28326        37.8
# 1  1003  Baldwin County  Alabama           AL  101188  106919        42.8
# 2  1005  Barbour County  Alabama           AL   13697   12085        39.9
# 3  1007     Bibb County  Alabama           AL   12152   10375        39.9
# 4  1009   Blount County  Alabama           AL   28434   29211        40.8
#
#    population  female_percentage      lat_x  ...        date  cases  deaths  \
# 0       55200          51.315217  32.534923  ...  2021-07-30   7479     114
# 1      208107          51.376936  30.727479  ...  2021-07-30  24499     328
# 2       25782          46.873788  31.869581  ...  2021-07-30   2462      61
# 3       22527          46.055844  32.998628  ...  2021-07-30   2845      65
# 4       57645          50.673953  33.980869  ...  2021-07-30   7266     139
#
#    Rural-urban_Continuum_Code_2013 Urban_Influence_Code_2013 POVALL_2018  \
# 0                          Level 2                   Level 2        7587
# 1                          Level 3                   Level 2       21069
# 2                          Level 6                   Level 6        6788
# 3                          Level 1                   Level 1        4400
# 4                          Level 1                   Level 1        7527
#
#    PCTPOVALL_2018  POV017_2018  PCTPOV017_2018  MEDHHINC_2018
# 0            13.8         2509            19.3          59338
# 1             9.8         6442            13.9          57588
# 2            30.9         2242            43.9          34382
# 3            21.8         1238            27.8          46064
# 4            13.2         2374            18.0          50412
#
# [5 rows x 21 columns]

# %% [markdown]
# #### Merge time series county-level data

# %%
mergeCountyts = pd.merge(dfCounty, dfcovCnty, how='inner', on='fips', validate = "1:m")
mergeCountyts.head(5)
# Out:
#    fips        county_x  state_x state_code_x   male  female  median_age  \
# 0  1001  Autauga County  Alabama           AL  26874   28326        37.8
# 1  1001  Autauga County  Alabama           AL  26874   28326        37.8
# 2  1001  Autauga County  Alabama           AL  26874   28326        37.8
# 3  1001  Autauga County  Alabama           AL  26874   28326        37.8
# 4  1001  Autauga County  Alabama           AL  26874   28326        37.8
#
#    population  female_percentage      lat_x    long_x county_y  state_y  \
# 0       55200          51.315217  32.534923 -86.64273  Autauga  Alabama
# 1       55200          51.315217  32.534923 -86.64273  Autauga  Alabama
# 2       55200          51.315217  32.534923 -86.64273  Autauga  Alabama
# 3       55200          51.315217  32.534923 -86.64273  Autauga  Alabama
# 4       55200          51.315217  32.534923 -86.64273  Autauga  Alabama
#
#        lat_y     long_y        date  cases state_code_y  deaths
# 0  32.539527 -86.644082  2020-01-22      0           AL       0
# 1  32.539527 -86.644082  2020-01-23      0           AL       0
# 2  32.539527 -86.644082  2020-01-24      0           AL       0
# 3  32.539527 -86.644082  2020-01-25      0           AL       0
# 4  32.539527 -86.644082  2020-01-26      0           AL       0

# %%
mergeCouPovts = pd.merge(mergeCountyts, dfPoverty, how='inner', left_on='fips', right_on='FIPStxt', validate = "m:1")
mergeCouPovts.head(5)
# Out:
#    fips        county_x  state_x state_code_x   male  female  median_age  \
# 0  1001  Autauga County  Alabama           AL  26874   28326        37.8
# 1  1001  Autauga County  Alabama           AL  26874   28326        37.8
# 2  1001  Autauga County  Alabama           AL  26874   28326        37.8
# 3  1001  Autauga County  Alabama           AL  26874   28326        37.8
# 4  1001  Autauga County  Alabama           AL  26874   28326        37.8
#
#    population  female_percentage      lat_x  ...  FIPStxt Stabr  \
# 0       55200          51.315217  32.534923  ...     1001    AL
# 1       55200          51.315217  32.534923  ...     1001    AL
# 2       55200          51.315217  32.534923  ...     1001    AL
# 3       55200          51.315217  32.534923  ...     1001    AL
# 4       55200          51.315217  32.534923  ...     1001    AL
#
#         Area_name  Rural-urban_Continuum_Code_2013  Urban_Influence_Code_2013  \
# 0  Autauga County                          Level 2                    Level 2
# 1  Autauga County                          Level 2                    Level 2
# 2  Autauga County                          Level 2                    Level 2
# 3  Autauga County                          Level 2                    Level 2
# 4  Autauga County                          Level 2                    Level 2
#
#   POVALL_2018  PCTPOVALL_2018 POV017_2018  PCTPOV017_2018  MEDHHINC_2018
# 0        7587            13.8        2509            19.3          59338
# 1        7587            13.8        2509            19.3          59338
# 2        7587            13.8        2509            19.3          59338
# 3        7587            13.8        2509            19.3          59338
# 4        7587            13.8        2509            19.3          59338
#
# [5 rows x 29 columns]

# %%
mergeCouPovts.isnull().sum()
# Out:
# fips                                 0
# county_x                             0
# state_x                              0
# state_code_x                       556
# male                                 0
# female                               0
# median_age                           0
# population                           0
# female_percentage                    0
# lat_x                                0
# long_x                               0
# county_y                             0
# state_y                              0
# lat_y                                0
# long_y                               0
# date                                 0
# cases                                0
# state_code_y                       556
# deaths                               0
# FIPStxt                              0
# Stabr                                0
# Area_name                            0
# Rural-urban_Continuum_Code_2013      0
# Urban_Influence_Code_2013            0
# POVALL_2018                          0
# PCTPOVALL_2018                       0
# POV017_2018                          0
# PCTPOV017_2018                       0
# MEDHHINC_2018                        0
# dtype: int64

# %%
mergeCouPovts[mergeCouPovts.state_code_x.isnull()].county_x.unique()
# Out:
# array(['District of Columbia'], dtype=object)

# %%
mergeCouPovts[mergeCouPovts.state_code_y.isnull()].county_x.unique()
# Out:
# array(['District of Columbia'], dtype=object)

# %% [markdown]
# Similarly, the missing values here are also due to District of Columbia not having a state code.

# %%
county_ts = mergeCouPovts[['fips', 'county_x', 'state_x', 'state_code_x', 'male', 'female',
       'median_age', 'population', 'female_percentage', 'lat_x', 'long_x', 'date', 'cases',
       'deaths', 'Rural-urban_Continuum_Code_2013', 'Urban_Influence_Code_2013',
       'POVALL_2018', 'PCTPOVALL_2018', 'POV017_2018', 'PCTPOV017_2018',
       'MEDHHINC_2018']]

# %% [markdown]
# Also, we removed the redundant columns like the current data.

# %%
county_ts.head()
# Out:
#    fips        county_x  state_x state_code_x   male  female  median_age  \
# 0  1001  Autauga County  Alabama           AL  26874   28326        37.8
# 1  1001  Autauga County  Alabama           AL  26874   28326        37.8
# 2  1001  Autauga County  Alabama           AL  26874   28326        37.8
# 3  1001  Autauga County  Alabama           AL  26874   28326        37.8
# 4  1001  Autauga County  Alabama           AL  26874   28326        37.8
#
#    population  female_percentage      lat_x  ...        date cases  deaths  \
# 0       55200          51.315217  32.534923  ...  2020-01-22     0       0
# 1       55200          51.315217  32.534923  ...  2020-01-23     0       0
# 2       55200          51.315217  32.534923  ...  2020-01-24     0       0
# 3       55200          51.315217  32.534923  ...  2020-01-25     0       0
# 4       55200          51.315217  32.534923  ...  2020-01-26     0       0
#
#    Rural-urban_Continuum_Code_2013 Urban_Influence_Code_2013 POVALL_2018  \
# 0                          Level 2                   Level 2        7587
# 1                          Level 2                   Level 2        7587
# 2                          Level 2                   Level 2        7587
# 3                          Level 2                   Level 2        7587
# 4                          Level 2                   Level 2        7587
#
#    PCTPOVALL_2018  POV017_2018  PCTPOV017_2018  MEDHHINC_2018
# 0            13.8         2509            19.3          59338
# 1            13.8         2509            19.3          59338
# 2            13.8         2509            19.3          59338
# 3            13.8         2509            19.3          59338
# 4            13.8         2509            19.3          59338
#
# [5 rows x 21 columns]

# %% [markdown]
# ## Merge state-level data

# %% [markdown]
# #### Merge current state-level data

# %%
mergeCovState = pd.merge(dfcovSt_current, state_pop, how='inner', on = 'state')
mergeCovState.head()
# Out:
#         state        date    cases  deaths      male    female  population  \
# 0     Alabama  2021-07-30   577463   11510   2355799   2508881     4864680
# 1      Alaska  2021-07-30    75486     389    385579    352937      738516
# 2     Arizona  2021-07-30   925169   18224   3453439   3493246     6946685
# 3    Arkansas  2021-07-30   385113    6123   1468412   1522259     2990671
# 4  California  2021-07-30  3956303   64423  19453769  19694991    39148760
#
#    female_proportion
# 0           0.515734
# 1           0.477900
# 2           0.502865
# 3           0.509002
# 4           0.503081

# %%
mergeCovStatePov = pd.merge(mergeCovState, dfPoverty, how = "inner", left_on = "state", right_on = "Area_name")
mergeCovStatePov
# Out:
#                    state        date    cases  deaths      male    female  \
# 0                Alabama  2021-07-30   577463   11510   2355799   2508881
# 1                 Alaska  2021-07-30    75486     389    385579    352937
# 2                Arizona  2021-07-30   925169   18224   3453439   3493246
# 3               Arkansas  2021-07-30   385113    6123   1468412   1522259
# 4             California  2021-07-30  3956303   64423  19453769  19694991
# 5               Colorado  2021-07-30   575082    6945   2780831   2750310
# 6            Connecticut  2021-07-30   354335    8293   1747131   1834373
# 7               Delaware  2021-07-30   111275    1830    459570    489925
# 8   District of Columbia  2021-07-30    50398    1149    324881    359617
# 9   District of Columbia  2021-07-30    50398    1149    324881    359617
# 10               Florida  2021-07-30  2634234   39079  10071925  10526214
# 11               Georgia  2021-07-30  1179449   21676   5012229   5285255
# 12                Hawaii  2021-07-30    41925     537    713772    708257
# 13                 Idaho  2021-07-30   200484    2197    845564    842245
# 14              Illinois  2021-07-30  1419611   25873   6295915   6525582
# 15               Indiana  2021-07-30   771299   14005   3271068   3366358
# 16                  Iowa  2021-07-30   378831    6183   1554481   1578018
# 17                Kansas  2021-07-30   333850    5261   1449413   1459363
# 18              Kentucky  2021-07-30   482599    7334   2186715   2253489
# 19             Louisiana  2021-07-30   541679   10999   2279968   2383648
# 20                 Maine  2021-07-30    70372     899    652299    680514
# 21              Maryland  2021-07-30   467961    9818   2910323   3093112
# 22         Massachusetts  2021-07-30   716771   18076   3313979   3516214
# 23              Michigan  2021-07-30   984016   21028   4899118   5058370
# 24             Minnesota  2021-07-30   612701    7761   2751748   2775610
# 25           Mississippi  2021-07-30   343505    7543   1450379   1538383
# 26              Missouri  2021-07-30   634482    9464   2988772   3101290
# 27               Montana  2021-07-30   116366    1704    524220    517512
# 28              Nebraska  2021-07-30   228450    2280    949910    954850
# 29                Nevada  2021-07-30   356401    5912   1467165   1455684
# 30         New Hampshire  2021-07-30   100657    1387    664983    678639
# 31            New Jersey  2021-07-30  1038171   26595   4335930   4545915
# 32            New Mexico  2021-07-30   210416    4410   1035850   1056584
# 33              New York  2021-07-30  2147318   53632   9519555  10098898
# 34        North Carolina  2021-07-30  1048076   13635   4944759   5210865
# 35          North Dakota  2021-07-30   111570    1570    386183    366018
# 36                  Ohio  2021-07-30  1127808   20492   5703967   5937912
# 37              Oklahoma  2021-07-30   480635    7485   1941576   1976561
# 38                Oregon  2021-07-30   219755    2858   2023021   2058922
# 39          Pennsylvania  2021-07-30  1229002   27850   6263189   6527992
# 40          Rhode Island  2021-07-30   154339    2740    513332    543279
# 41        South Carolina  2021-07-30   617148    9904   2405726   2550199
# 42          South Dakota  2021-07-30   125225    2045    435761    428528
# 43             Tennessee  2021-07-30   893554   12724   3243678   3407411
# 44                 Texas  2021-07-30  3133639   53248  13849775  14035420
# 45                  Utah  2021-07-30   325592    1670   1532768   1512582
# 46               Vermont  2021-07-30    24889     260    307973    317004
# 47              Virginia  2021-07-30   694384   11532   4138574   4275200
# 48            Washington  2021-07-30   473076    6122   3645665   3648671
# 49         West Virginia  2021-07-30   167016    2946    904196    924858
# 50             Wisconsin  2021-07-30   687198    8290   2872376   2906018
# 51               Wyoming  2021-07-30    65127     776    296979    284857
#
#     population  female_proportion  FIPStxt Stabr             Area_name  \
# 0      4864680           0.515734     1000    AL               Alabama
# 1       738516           0.477900     2000    AK                Alaska
# 2      6946685           0.502865     4000    AZ               Arizona
# 3      2990671           0.509002     5000    AR              Arkansas
# 4     39148760           0.503081     6000    CA            California
# 5      5531141           0.497241     8000    CO              Colorado
# 6      3581504           0.512180     9000    CT           Connecticut
# 7       949495           0.515985    10000    DE              Delaware
# 8       684498           0.525373    11000    DC  District of Columbia
# 9       684498           0.525373    11001    DC  District of Columbia
# 10    20598139           0.511027    12000    FL               Florida
# 11    10297484           0.513257    13000    GA               Georgia
# 12     1422029           0.498061    15000    HI                Hawaii
# 13     1687809           0.499017    16000    ID                 Idaho
# 14    12821497           0.508956    17000    IL              Illinois
# 15     6637426           0.507178    18000    IN               Indiana
# 16     3132499           0.503757    19000    IA                  Iowa
# 17     2908776           0.501710    20000    KS                Kansas
# 18     4440204           0.507519    21000    KY              Kentucky
# 19     4663616           0.511116    22000    LA             Louisiana
# 20     1332813           0.510585    23000    ME                 Maine
# 21     6003435           0.515224    24000    MD              Maryland
# 22     6830193           0.514804    25000    MA         Massachusetts
# 23     9957488           0.507997    26000    MI              Michigan
# 24     5527358           0.502159    27000    MN             Minnesota
# 25     2988762           0.514722    28000    MS           Mississippi
# 26     6090062           0.509238    29000    MO              Missouri
# 27     1041732           0.496780    30000    MT               Montana
# 28     1904760           0.501297    31000    NE              Nebraska
# 29     2922849           0.498036    32000    NV                Nevada
# 30     1343622           0.505082    33000    NH         New Hampshire
# 31     8881845           0.511821    34000    NJ            New Jersey
# 32     2092434           0.504955    35000    NM            New Mexico
# 33    19618453           0.514765    36000    NY              New York
# 34    10155624           0.513101    37000    NC        North Carolina
# 35      752201           0.486596    38000    ND          North Dakota
# 36    11641879           0.510048    39000    OH                  Ohio
# 37     3918137           0.504464    40000    OK              Oklahoma
# 38     4081943           0.504398    41000    OR                Oregon
# 39    12791181           0.510351    42000    PA          Pennsylvania
# 40     1056611           0.514171    44000    RI          Rhode Island
# 41     4955925           0.514576    45000    SC        South Carolina
# 42      864289           0.495816    46000    SD          South Dakota
# 43     6651089           0.512309    47000    TN             Tennessee
# 44    27885195           0.503329    48000    TX                 Texas
# 45     3045350           0.496686    49000    UT                  Utah
# 46      624977           0.507225    50000    VT               Vermont
# 47     8413774           0.508119    51000    VA              Virginia
# 48     7294336           0.500206    53000    WA            Washington
# 49     1829054           0.505648    54000    WV         West Virginia
# 50     5778394           0.502911    55000    WI             Wisconsin
# 51      581836           0.489583    56000    WY               Wyoming
#
#    Rural-urban_Continuum_Code_2013 Urban_Influence_Code_2013  POVALL_2018  \
# 0                              NaN                       NaN       801758
# 1                              NaN                       NaN        80224
# 2                              NaN                       NaN       990291
# 3                              NaN                       NaN       492306
# 4                              NaN                       NaN      4972955
# 5                              NaN                       NaN       540579
# 6                              NaN                       NaN       358519
# 7                              NaN                       NaN       114691
# 8                              NaN                       NaN       107806
# 9                          Level 1                   Level 1       107806
# 10                             NaN                       NaN      2854438
# 11                             NaN                       NaN      1484439
# 12                             NaN                       NaN       124400
# 13                             NaN                       NaN       201804
# 14                             NaN                       NaN      1509348
# 15                             NaN                       NaN       844165
# 16                             NaN                       NaN       342574
# 17                             NaN                       NaN       336892
# 18                             NaN                       NaN       723053
# 19                             NaN                       NaN       848005
# 20                             NaN                       NaN       151458
# 21                             NaN                       NaN       538824
# 22                             NaN                       NaN       668402
# 23                             NaN                       NaN      1369235
# 24                             NaN                       NaN       527445
# 25                             NaN                       NaN       571402
# 26                             NaN                       NaN       785343
# 27                             NaN                       NaN       134185
# 28                             NaN                       NaN       205393
# 29                             NaN                       NaN       391347
# 30                             NaN                       NaN       100076
# 31                             NaN                       NaN       831386
# 32                             NaN                       NaN       386739
# 33                             NaN                       NaN      2603303
# 34                             NaN                       NaN      1422154
# 35                             NaN                       NaN        77959
# 36                             NaN                       NaN      1568586
# 37                             NaN                       NaN       593936
# 38                             NaN                       NaN       516014
# 39                             NaN                       NaN      1517936
# 40                             NaN                       NaN       130538
# 41                             NaN                       NaN       750582
# 42                             NaN                       NaN       109814
# 43                             NaN                       NaN      1003055
# 44                             NaN                       NaN      4181623
# 45                             NaN                       NaN       283562
# 46                             NaN                       NaN        64431
# 47                             NaN                       NaN       884898
# 48                             NaN                       NaN       761941
# 49                             NaN                       NaN       305656
# 50                             NaN                       NaN       626748
# 51                             NaN                       NaN        60097
#
#     PCTPOVALL_2018  POV017_2018  PCTPOV017_2018  MEDHHINC_2018
# 0             16.8       255613            23.9          49881
# 1             11.1        26096            14.5          74912
# 2             14.1       328780            20.4          59079
# 3             16.8       164056            23.8          47094
# 4             12.8      1539628            17.4          75250
# 5              9.7       151618            12.1          71949
# 6             10.3       100250            13.8          76366
# 7             12.2        35031            17.6          65467
# 8             16.1        30803            24.5          82533
# 9             16.1        30803            24.5          82533
# 10            13.7       831420            20.0          55433
# 11            14.5       516311            21.0          58634
# 12             9.0        35184            11.8          80527
# 13            11.7        62392            14.2          55524
# 14            12.1       457282            16.2          65063
# 15            13.0       268470            17.5          55725
# 16            11.2        96859            13.5          60071
# 17            11.9       102616            14.8          58150
# 18            16.7       219283            22.3          50189
# 19            18.7       286532            26.5          48021
# 20            11.6        35960            14.8          55579
# 21             9.1       159872            12.1          83076
# 22            10.0       166516            12.4          79817
# 23            14.0       409201            19.3          56640
# 24             9.6       147732            11.5          70295
# 25            19.8       195794            28.2          44740
# 26            13.2       245703            18.3          54412
# 27            12.9        36711            16.4          55248
# 28            11.0        60389            12.9          59724
# 29            13.1       124828            18.4          58740
# 30             7.6        25379            10.1          75322
# 31             9.5       261055            13.5          81777
# 32            18.8       119378            25.3          47405
# 33            13.7       751694            18.8          67648
# 34            14.1       457103            20.2          53922
# 35            10.6        19332            11.0          65250
# 36            13.8       489053            19.2          56155
# 37            15.5       200399            21.4          51914
# 38            12.5       134073            15.7          63168
# 39            12.2       433329            16.7          60891
# 40            12.8        36239            18.0          63787
# 41            15.2       241192            22.1          52449
# 42            12.9        34211            16.1          57041
# 43            15.2       322616            21.8          52366
# 44            14.9      1543228            21.1          60632
# 45             9.1        89015             9.7          71381
# 46            10.7        13791            12.2          60917
# 47            10.7       253481            13.8          72600
# 48            10.3       205912            12.6          74023
# 49            17.4        82213            23.2          44038
# 50            11.1       176595            14.1          60779
# 51            10.7        17314            13.1          62259

# %% [markdown]
# We found out that there are two observations of District of Columbia, thus we removed the second one.

# %%
mergeCovStatePov.drop(mergeCovStatePov[mergeCovStatePov.FIPStxt == 11001].index, inplace = True)
mergeCovStatePov
# Out:
#                    state        date    cases  deaths      male    female  \
# 0                Alabama  2021-07-30   577463   11510   2355799   2508881
# 1                 Alaska  2021-07-30    75486     389    385579    352937
# 2                Arizona  2021-07-30   925169   18224   3453439   3493246
# 3               Arkansas  2021-07-30   385113    6123   1468412   1522259
# 4             California  2021-07-30  3956303   64423  19453769  19694991
# 5               Colorado  2021-07-30   575082    6945   2780831   2750310
# 6            Connecticut  2021-07-30   354335    8293   1747131   1834373
# 7               Delaware  2021-07-30   111275    1830    459570    489925
# 8   District of Columbia  2021-07-30    50398    1149    324881    359617
# 10               Florida  2021-07-30  2634234   39079  10071925  10526214
# 11               Georgia  2021-07-30  1179449   21676   5012229   5285255
# 12                Hawaii  2021-07-30    41925     537    713772    708257
# 13                 Idaho  2021-07-30   200484    2197    845564    842245
# 14              Illinois  2021-07-30  1419611   25873   6295915   6525582
# 15               Indiana  2021-07-30   771299   14005   3271068   3366358
# 16                  Iowa  2021-07-30   378831    6183   1554481   1578018
# 17                Kansas  2021-07-30   333850    5261   1449413   1459363
# 18              Kentucky  2021-07-30   482599    7334   2186715   2253489
# 19             Louisiana  2021-07-30   541679   10999   2279968   2383648
# 20                 Maine  2021-07-30    70372     899    652299    680514
# 21              Maryland  2021-07-30   467961    9818   2910323   3093112
# 22         Massachusetts  2021-07-30   716771   18076   3313979   3516214
# 23              Michigan  2021-07-30   984016   21028   4899118   5058370
# 24             Minnesota  2021-07-30   612701    7761   2751748   2775610
# 25           Mississippi  2021-07-30   343505    7543   1450379   1538383
# 26              Missouri  2021-07-30   634482    9464   2988772   3101290
# 27               Montana  2021-07-30   116366    1704    524220    517512
# 28              Nebraska  2021-07-30   228450    2280    949910    954850
# 29                Nevada  2021-07-30   356401    5912   1467165   1455684
# 30         New Hampshire  2021-07-30   100657    1387    664983    678639
# 31            New Jersey  2021-07-30  1038171   26595   4335930   4545915
# 32            New Mexico  2021-07-30   210416    4410   1035850   1056584
# 33              New York  2021-07-30  2147318   53632   9519555  10098898
# 34        North Carolina  2021-07-30  1048076   13635   4944759   5210865
# 35          North Dakota  2021-07-30   111570    1570    386183    366018
# 36                  Ohio  2021-07-30  1127808   20492   5703967   5937912
# 37              Oklahoma  2021-07-30   480635    7485   1941576   1976561
# 38                Oregon  2021-07-30   219755    2858   2023021   2058922
# 39          Pennsylvania  2021-07-30  1229002   27850   6263189   6527992
# 40          Rhode Island  2021-07-30   154339    2740    513332    543279
# 41        South Carolina  2021-07-30   617148    9904   2405726   2550199
# 42          South Dakota  2021-07-30   125225    2045    435761    428528
# 43             Tennessee  2021-07-30   893554   12724   3243678   3407411
# 44                 Texas  2021-07-30  3133639   53248  13849775  14035420
# 45                  Utah  2021-07-30   325592    1670   1532768   1512582
# 46               Vermont  2021-07-30    24889     260    307973    317004
# 47              Virginia  2021-07-30   694384   11532   4138574   4275200
# 48            Washington  2021-07-30   473076    6122   3645665   3648671
# 49         West Virginia  2021-07-30   167016    2946    904196    924858
# 50             Wisconsin  2021-07-30   687198    8290   2872376   2906018
# 51               Wyoming  2021-07-30    65127     776    296979    284857
#
#     population  female_proportion  FIPStxt Stabr             Area_name  \
# 0      4864680           0.515734     1000    AL               Alabama
# 1       738516           0.477900     2000    AK                Alaska
# 2      6946685           0.502865     4000    AZ               Arizona
# 3      2990671           0.509002     5000    AR              Arkansas
# 4     39148760           0.503081     6000    CA            California
# 5      5531141           0.497241     8000    CO              Colorado
# 6      3581504           0.512180     9000    CT           Connecticut
# 7       949495           0.515985    10000    DE              Delaware
# 8       684498           0.525373    11000    DC  District of Columbia
# 10    20598139           0.511027    12000    FL               Florida
# 11    10297484           0.513257    13000    GA               Georgia
# 12     1422029           0.498061    15000    HI                Hawaii
# 13     1687809           0.499017    16000    ID                 Idaho
# 14    12821497           0.508956    17000    IL              Illinois
# 15     6637426           0.507178    18000    IN               Indiana
# 16     3132499           0.503757    19000    IA                  Iowa
# 17     2908776           0.501710    20000    KS                Kansas
# 18     4440204           0.507519    21000    KY              Kentucky
# 19     4663616           0.511116    22000    LA             Louisiana
# 20     1332813           0.510585    23000    ME                 Maine
# 21     6003435           0.515224    24000    MD              Maryland
# 22     6830193           0.514804    25000    MA         Massachusetts
# 23     9957488           0.507997    26000    MI              Michigan
# 24     5527358           0.502159    27000    MN             Minnesota
# 25     2988762           0.514722    28000    MS           Mississippi
# 26     6090062           0.509238    29000    MO              Missouri
# 27     1041732           0.496780    30000    MT               Montana
# 28     1904760           0.501297    31000    NE              Nebraska
# 29     2922849           0.498036    32000    NV                Nevada
# 30     1343622           0.505082    33000    NH         New Hampshire
# 31     8881845           0.511821    34000    NJ            New Jersey
# 32     2092434           0.504955    35000    NM            New Mexico
# 33    19618453           0.514765    36000    NY              New York
# 34    10155624           0.513101    37000    NC        North Carolina
# 35      752201           0.486596    38000    ND          North Dakota
# 36    11641879           0.510048    39000    OH                  Ohio
# 37     3918137           0.504464    40000    OK              Oklahoma
# 38     4081943           0.504398    41000    OR                Oregon
# 39    12791181           0.510351    42000    PA          Pennsylvania
# 40     1056611           0.514171    44000    RI          Rhode Island
# 41     4955925           0.514576    45000    SC        South Carolina
# 42      864289           0.495816    46000    SD          South Dakota
# 43     6651089           0.512309    47000    TN             Tennessee
# 44    27885195           0.503329    48000    TX                 Texas
# 45     3045350           0.496686    49000    UT                  Utah
# 46      624977           0.507225    50000    VT               Vermont
# 47     8413774           0.508119    51000    VA              Virginia
# 48     7294336           0.500206    53000    WA            Washington
# 49     1829054           0.505648    54000    WV         West Virginia
# 50     5778394           0.502911    55000    WI             Wisconsin
# 51      581836           0.489583    56000    WY               Wyoming
#
#    Rural-urban_Continuum_Code_2013 Urban_Influence_Code_2013  POVALL_2018  \
# 0                              NaN                       NaN       801758
# 1                              NaN                       NaN        80224
# 2                              NaN                       NaN       990291
# 3                              NaN                       NaN       492306
# 4                              NaN                       NaN      4972955
# 5                              NaN                       NaN       540579
# 6                              NaN                       NaN       358519
# 7                              NaN                       NaN       114691
# 8                              NaN                       NaN       107806
# 10                             NaN                       NaN      2854438
# 11                             NaN                       NaN      1484439
# 12                             NaN                       NaN       124400
# 13                             NaN                       NaN       201804
# 14                             NaN                       NaN      1509348
# 15                             NaN                       NaN       844165
# 16                             NaN                       NaN       342574
# 17                             NaN                       NaN       336892
# 18                             NaN                       NaN       723053
# 19                             NaN                       NaN       848005
# 20                             NaN                       NaN       151458
# 21                             NaN                       NaN       538824
# 22                             NaN                       NaN       668402
# 23                             NaN                       NaN      1369235
# 24                             NaN                       NaN       527445
# 25                             NaN                       NaN       571402
# 26                             NaN                       NaN       785343
# 27                             NaN                       NaN       134185
# 28                             NaN                       NaN       205393
# 29                             NaN                       NaN       391347
# 30                             NaN                       NaN       100076
# 31                             NaN                       NaN       831386
# 32                             NaN                       NaN       386739
# 33                             NaN                       NaN      2603303
# 34                             NaN                       NaN      1422154
# 35                             NaN                       NaN        77959
# 36                             NaN                       NaN      1568586
# 37                             NaN                       NaN       593936
# 38                             NaN                       NaN       516014
# 39                             NaN                       NaN      1517936
# 40                             NaN                       NaN       130538
# 41                             NaN                       NaN       750582
# 42                             NaN                       NaN       109814
# 43                             NaN                       NaN      1003055
# 44                             NaN                       NaN      4181623
# 45                             NaN                       NaN       283562
# 46                             NaN                       NaN        64431
# 47                             NaN                       NaN       884898
# 48                             NaN                       NaN       761941
# 49                             NaN                       NaN       305656
# 50                             NaN                       NaN       626748
# 51                             NaN                       NaN        60097
#
#     PCTPOVALL_2018  POV017_2018  PCTPOV017_2018  MEDHHINC_2018
# 0             16.8       255613            23.9          49881
# 1             11.1        26096            14.5          74912
# 2             14.1       328780            20.4          59079
# 3             16.8       164056            23.8          47094
# 4             12.8      1539628            17.4          75250
# 5              9.7       151618            12.1          71949
# 6             10.3       100250            13.8          76366
# 7             12.2        35031            17.6          65467
# 8             16.1        30803            24.5          82533
# 10            13.7       831420            20.0          55433
# 11            14.5       516311            21.0          58634
# 12             9.0        35184            11.8          80527
# 13            11.7        62392            14.2          55524
# 14            12.1       457282            16.2          65063
# 15            13.0       268470            17.5          55725
# 16            11.2        96859            13.5          60071
# 17            11.9       102616            14.8          58150
# 18            16.7       219283            22.3          50189
# 19            18.7       286532            26.5          48021
# 20            11.6        35960            14.8          55579
# 21             9.1       159872            12.1          83076
# 22            10.0       166516            12.4          79817
# 23            14.0       409201            19.3          56640
# 24             9.6       147732            11.5          70295
# 25            19.8       195794            28.2          44740
# 26            13.2       245703            18.3          54412
# 27            12.9        36711            16.4          55248
# 28            11.0        60389            12.9          59724
# 29            13.1       124828            18.4          58740
# 30             7.6        25379            10.1          75322
# 31             9.5       261055            13.5          81777
# 32            18.8       119378            25.3          47405
# 33            13.7       751694            18.8          67648
# 34            14.1       457103            20.2          53922
# 35            10.6        19332            11.0          65250
# 36            13.8       489053            19.2          56155
# 37            15.5       200399            21.4          51914
# 38            12.5       134073            15.7          63168
# 39            12.2       433329            16.7          60891
# 40            12.8        36239            18.0          63787
# 41            15.2       241192            22.1          52449
# 42            12.9        34211            16.1          57041
# 43            15.2       322616            21.8          52366
# 44            14.9      1543228            21.1          60632
# 45             9.1        89015             9.7          71381
# 46            10.7        13791            12.2          60917
# 47            10.7       253481            13.8          72600
# 48            10.3       205912            12.6          74023
# 49            17.4        82213            23.2          44038
# 50            11.1       176595            14.1          60779
# 51            10.7        17314            13.1          62259

# %% [markdown]
# Here, we use left join to be consistent with time series merging, when we need to include missing values for vaccination data before vaccination starting date.

# %%
mergeCovStatePovVac = pd.merge(mergeCovStatePov, dfvac_current, how = "left", left_on = "state", right_on = "location")
mergeCovStatePovVac
# Out:
#                    state      date_x    cases  deaths      male    female  \
# 0                Alabama  2021-07-30   577463   11510   2355799   2508881
# 1                 Alaska  2021-07-30    75486     389    385579    352937
# 2                Arizona  2021-07-30   925169   18224   3453439   3493246
# 3               Arkansas  2021-07-30   385113    6123   1468412   1522259
# 4             California  2021-07-30  3956303   64423  19453769  19694991
# 5               Colorado  2021-07-30   575082    6945   2780831   2750310
# 6            Connecticut  2021-07-30   354335    8293   1747131   1834373
# 7               Delaware  2021-07-30   111275    1830    459570    489925
# 8   District of Columbia  2021-07-30    50398    1149    324881    359617
# 9                Florida  2021-07-30  2634234   39079  10071925  10526214
# 10               Georgia  2021-07-30  1179449   21676   5012229   5285255
# 11                Hawaii  2021-07-30    41925     537    713772    708257
# 12                 Idaho  2021-07-30   200484    2197    845564    842245
# 13              Illinois  2021-07-30  1419611   25873   6295915   6525582
# 14               Indiana  2021-07-30   771299   14005   3271068   3366358
# 15                  Iowa  2021-07-30   378831    6183   1554481   1578018
# 16                Kansas  2021-07-30   333850    5261   1449413   1459363
# 17              Kentucky  2021-07-30   482599    7334   2186715   2253489
# 18             Louisiana  2021-07-30   541679   10999   2279968   2383648
# 19                 Maine  2021-07-30    70372     899    652299    680514
# 20              Maryland  2021-07-30   467961    9818   2910323   3093112
# 21         Massachusetts  2021-07-30   716771   18076   3313979   3516214
# 22              Michigan  2021-07-30   984016   21028   4899118   5058370
# 23             Minnesota  2021-07-30   612701    7761   2751748   2775610
# 24           Mississippi  2021-07-30   343505    7543   1450379   1538383
# 25              Missouri  2021-07-30   634482    9464   2988772   3101290
# 26               Montana  2021-07-30   116366    1704    524220    517512
# 27              Nebraska  2021-07-30   228450    2280    949910    954850
# 28                Nevada  2021-07-30   356401    5912   1467165   1455684
# 29         New Hampshire  2021-07-30   100657    1387    664983    678639
# 30            New Jersey  2021-07-30  1038171   26595   4335930   4545915
# 31            New Mexico  2021-07-30   210416    4410   1035850   1056584
# 32              New York  2021-07-30  2147318   53632   9519555  10098898
# 33        North Carolina  2021-07-30  1048076   13635   4944759   5210865
# 34          North Dakota  2021-07-30   111570    1570    386183    366018
# 35                  Ohio  2021-07-30  1127808   20492   5703967   5937912
# 36              Oklahoma  2021-07-30   480635    7485   1941576   1976561
# 37                Oregon  2021-07-30   219755    2858   2023021   2058922
# 38          Pennsylvania  2021-07-30  1229002   27850   6263189   6527992
# 39          Rhode Island  2021-07-30   154339    2740    513332    543279
# 40        South Carolina  2021-07-30   617148    9904   2405726   2550199
# 41          South Dakota  2021-07-30   125225    2045    435761    428528
# 42             Tennessee  2021-07-30   893554   12724   3243678   3407411
# 43                 Texas  2021-07-30  3133639   53248  13849775  14035420
# 44                  Utah  2021-07-30   325592    1670   1532768   1512582
# 45               Vermont  2021-07-30    24889     260    307973    317004
# 46              Virginia  2021-07-30   694384   11532   4138574   4275200
# 47            Washington  2021-07-30   473076    6122   3645665   3648671
# 48         West Virginia  2021-07-30   167016    2946    904196    924858
# 49             Wisconsin  2021-07-30   687198    8290   2872376   2906018
# 50               Wyoming  2021-07-30    65127     776    296979    284857
#
#     population  female_proportion  FIPStxt Stabr  ... MEDHHINC_2018  \
# 0      4864680           0.515734     1000    AL  ...         49881
# 1       738516           0.477900     2000    AK  ...         74912
# 2      6946685           0.502865     4000    AZ  ...         59079
# 3      2990671           0.509002     5000    AR  ...         47094
# 4     39148760           0.503081     6000    CA  ...         75250
# 5      5531141           0.497241     8000    CO  ...         71949
# 6      3581504           0.512180     9000    CT  ...         76366
# 7       949495           0.515985    10000    DE  ...         65467
# 8       684498           0.525373    11000    DC  ...         82533
# 9     20598139           0.511027    12000    FL  ...         55433
# 10    10297484           0.513257    13000    GA  ...         58634
# 11     1422029           0.498061    15000    HI  ...         80527
# 12     1687809           0.499017    16000    ID  ...         55524
# 13    12821497           0.508956    17000    IL  ...         65063
# 14     6637426           0.507178    18000    IN  ...         55725
# 15     3132499           0.503757    19000    IA  ...         60071
# 16     2908776           0.501710    20000    KS  ...         58150
# 17     4440204           0.507519    21000    KY  ...         50189
# 18     4663616           0.511116    22000    LA  ...         48021
# 19     1332813           0.510585    23000    ME  ...         55579
# 20     6003435           0.515224    24000    MD  ...         83076
# 21     6830193           0.514804    25000    MA  ...         79817
# 22     9957488           0.507997    26000    MI  ...         56640
# 23     5527358           0.502159    27000    MN  ...         70295
# 24     2988762           0.514722    28000    MS  ...         44740
# 25     6090062           0.509238    29000    MO  ...         54412
# 26     1041732           0.496780    30000    MT  ...         55248
# 27     1904760           0.501297    31000    NE  ...         59724
# 28     2922849           0.498036    32000    NV  ...         58740
# 29     1343622           0.505082    33000    NH  ...         75322
# 30     8881845           0.511821    34000    NJ  ...         81777
# 31     2092434           0.504955    35000    NM  ...         47405
# 32    19618453           0.514765    36000    NY  ...         67648
# 33    10155624           0.513101    37000    NC  ...         53922
# 34      752201           0.486596    38000    ND  ...         65250
# 35    11641879           0.510048    39000    OH  ...         56155
# 36     3918137           0.504464    40000    OK  ...         51914
# 37     4081943           0.504398    41000    OR  ...         63168
# 38    12791181           0.510351    42000    PA  ...         60891
# 39     1056611           0.514171    44000    RI  ...         63787
# 40     4955925           0.514576    45000    SC  ...         52449
# 41      864289           0.495816    46000    SD  ...         57041
# 42     6651089           0.512309    47000    TN  ...         52366
# 43    27885195           0.503329    48000    TX  ...         60632
# 44     3045350           0.496686    49000    UT  ...         71381
# 45      624977           0.507225    50000    VT  ...         60917
# 46     8413774           0.508119    51000    VA  ...         72600
# 47     7294336           0.500206    53000    WA  ...         74023
# 48     1829054           0.505648    54000    WV  ...         44038
# 49     5778394           0.502911    55000    WI  ...         60779
# 50      581836           0.489583    56000    WY  ...         62259
#
#         date_y              location  people_vaccinated  \
# 0   2021-07-30               Alabama          2116551.0
# 1   2021-07-30                Alaska           376154.0
# 2   2021-07-30               Arizona          3853257.0
# 3   2021-07-30              Arkansas          1405459.0
# 4   2021-07-30            California         25549997.0
# 5   2021-07-30              Colorado          3464422.0
# 6   2021-07-30           Connecticut          2487176.0
# 7   2021-07-30              Delaware           589786.0
# 8   2021-07-30  District of Columbia           450511.0
# 9   2021-07-30               Florida         12344424.0
# 10  2021-07-30               Georgia          4910269.0
# 11  2021-07-30                Hawaii          1009978.0
# 12  2021-07-30                 Idaho           733952.0
# 13  2021-07-30              Illinois          7884514.0
# 14  2021-07-30               Indiana          3173596.0
# 15  2021-07-30                  Iowa          1678551.0
# 16  2021-07-30                Kansas          1548703.0
# 17  2021-07-30              Kentucky          2320180.0
# 18  2021-07-30             Louisiana          1958099.0
# 19  2021-07-30                 Maine           918580.0
# 20  2021-07-30              Maryland          3906200.0
# 21  2021-07-30         Massachusetts          5000631.0
# 22  2021-07-30              Michigan          5297149.0
# 23  2021-07-30             Minnesota          3314049.0
# 24  2021-07-30           Mississippi          1182948.0
# 25  2021-07-30              Missouri          2979857.0
# 26  2021-07-30               Montana           527498.0
# 27  2021-07-30              Nebraska          1040464.0
# 28  2021-07-30                Nevada          1647017.0
# 29  2021-07-30         New Hampshire           878998.0
# 30  2021-07-30            New Jersey          5847756.0
# 31  2021-07-30            New Mexico          1369002.0
# 32  2021-07-30              New York         12242044.0
# 33  2021-07-30        North Carolina          5356957.0
# 34  2021-07-30          North Dakota           345841.0
# 35  2021-07-30                  Ohio          5818078.0
# 36  2021-07-30              Oklahoma          1890094.0
# 37  2021-07-30                Oregon          2556604.0
# 38  2021-07-30          Pennsylvania          8378102.0
# 39  2021-07-30          Rhode Island           712633.0
# 40  2021-07-30        South Carolina          2401300.0
# 41  2021-07-30          South Dakota           466042.0
# 42  2021-07-30             Tennessee          3046898.0
# 43  2021-07-30                 Texas         14922919.0
# 44  2021-07-30                  Utah          1663466.0
# 45  2021-07-30               Vermont           470908.0
# 46  2021-07-30              Virginia          5255419.0
# 47  2021-07-30            Washington          4863756.0
# 48  2021-07-30         West Virginia           824654.0
# 49  2021-07-30             Wisconsin          3233319.0
# 50  2021-07-30               Wyoming           240961.0
#
#     people_fully_vaccinated_per_hundred  total_vaccinations_per_hundred  \
# 0                                 34.33                           73.15
# 1                                 45.48                           95.19
# 2                                 45.19                           97.35
# 3                                 36.29                           80.61
# 4                                 52.73                          114.00
# 5                                 54.33                          112.18
# 6                                 63.20                          128.61
# 7                                 52.63                          111.72
# 8                                 54.67                          127.45
# 9                                 48.77                          104.66
# 10                                38.65                           84.20
# 11                                53.49                          121.29
# 12                                37.34                           76.74
# 13                                48.47                          107.42
# 14                                44.17                           90.04
# 15                                49.59                           99.45
# 16                                45.14                           92.54
# 17                                45.49                           93.68
# 18                                36.84                           78.03
# 19                                63.45                          123.82
# 20                                58.75                          119.06
# 21                                63.87                          132.51
# 22                                48.80                           97.99
# 23                                53.72                          107.68
# 24                                34.50                           72.23
# 25                                41.18                           88.76
# 26                                44.27                           90.91
# 27                                49.45                          100.21
# 28                                44.31                           96.02
# 29                                58.24                          117.00
# 30                                58.28                          116.59
# 31                                56.95                          118.15
# 32                                57.01                          117.73
# 33                                43.71                           92.50
# 34                                40.07                           86.89
# 35                                46.46                           94.71
# 36                                40.19                           87.20
# 37                                55.91                          112.31
# 38                                52.29                          113.64
# 39                                61.43                          125.30
# 40                                40.56                           85.47
# 41                                46.91                           96.07
# 42                                39.04                           84.05
# 43                                43.75                           94.27
# 44                                44.68                           93.38
# 45                                67.49                          139.79
# 46                                54.42                          113.18
# 47                                57.56                          118.05
# 48                                39.03                           82.98
# 49                                51.72                          105.70
# 50                                36.61                           77.16
#
#     people_fully_vaccinated  people_vaccinated_per_hundred daily_vaccinations  \
# 0                 1683367.0                          43.17            13131.0
# 1                  332678.0                          51.42              837.0
# 2                 3289110.0                          52.94            12063.0
# 3                 1095214.0                          46.57             9842.0
# 4                20834953.0                          64.66            82509.0
# 5                 3128681.0                          60.16             8922.0
# 6                 2253102.0                          69.76             6152.0
# 7                  512530.0                          60.57             1686.0
# 8                  385812.0                          63.83             1028.0
# 9                10474974.0                          57.48            58800.0
# 10                4103919.0                          46.25            27357.0
# 11                 757336.0                          71.33             1374.0
# 12                 667292.0                          41.07             1769.0
# 13                6142053.0                          62.22            21859.0
# 14                2973361.0                          47.14             9339.0
# 15                1564444.0                          53.20             3773.0
# 16                1314972.0                          53.16            18060.0
# 17                2032349.0                          51.93             7656.0
# 18                1712663.0                          42.12            13500.0
# 19                 852919.0                          68.34             1716.0
# 20                3551567.0                          64.61            11026.0
# 21                4402108.0                          72.55            10295.0
# 22                4873178.0                          53.04            10132.0
# 23                3029752.0                          58.76             7180.0
# 24                1026669.0                          39.75             8181.0
# 25                2527492.0                          48.55            14316.0
# 26                 473160.0                          49.36             1169.0
# 27                 956540.0                          53.79             3866.0
# 28                1364717.0                          53.47             7077.0
# 29                 791860.0                          64.65             1700.0
# 30                5176518.0                          65.84            19883.0
# 31                1194187.0                          65.29             3102.0
# 32               11091103.0                          62.93            37673.0
# 33                4584126.0                          51.08            18660.0
# 34                 305349.0                          45.38              846.0
# 35                5430840.0                          49.77            14399.0
# 36                1590417.0                          47.77             8113.0
# 37                2357975.0                          60.62             5331.0
# 38                6693606.0                          65.44            24401.0
# 39                 650713.0                          67.27             1765.0
# 40                2088129.0                          46.64             8674.0
# 41                 414977.0                          52.68             1260.0
# 42                2665810.0                          44.62            11959.0
# 43               12684799.0                          51.47            64934.0
# 44                1432276.0                          51.89             4979.0
# 45                 421106.0                          75.47              589.0
# 46                4644755.0                          61.57            14727.0
# 47                4382753.0                          63.87            12429.0
# 48                 699470.0                          46.01              485.0
# 49                3011405.0                          55.53             8964.0
# 50                 211874.0                          41.63              697.0
#
#    daily_vaccinations_per_million
# 0                          2678.0
# 1                          1144.0
# 2                          1657.0
# 3                          3261.0
# 4                          2088.0
# 5                          1549.0
# 6                          1726.0
# 7                          1731.0
# 8                          1457.0
# 9                          2738.0
# 10                         2577.0
# 11                          970.0
# 12                          990.0
# 13                         1725.0
# 14                         1387.0
# 15                         1196.0
# 16                         6199.0
# 17                         1714.0
# 18                         2904.0
# 19                         1277.0
# 20                         1824.0
# 21                         1494.0
# 22                         1015.0
# 23                         1273.0
# 24                         2749.0
# 25                         2333.0
# 26                         1094.0
# 27                         1999.0
# 28                         2298.0
# 29                         1250.0
# 30                         2239.0
# 31                         1479.0
# 32                         1937.0
# 33                         1779.0
# 34                         1110.0
# 35                         1232.0
# 36                         2050.0
# 37                         1264.0
# 38                         1906.0
# 39                         1666.0
# 40                         1685.0
# 41                         1424.0
# 42                         1751.0
# 43                         2239.0
# 44                         1553.0
# 45                          944.0
# 46                         1725.0
# 47                         1632.0
# 48                          271.0
# 49                         1540.0
# 50                         1204.0
#
# [51 rows x 27 columns]

# %%
mergeCovStatePovVac.columns
# Out:
# Index(['state', 'date_x', 'cases', 'deaths', 'male', 'female', 'population',
#        'female_proportion', 'FIPStxt', 'Stabr', 'Area_name',
#        'Rural-urban_Continuum_Code_2013', 'Urban_Influence_Code_2013',
#        'POVALL_2018', 'PCTPOVALL_2018', 'POV017_2018', 'PCTPOV017_2018',
#        'MEDHHINC_2018', 'date_y', 'location', 'people_vaccinated',
#        'people_fully_vaccinated_per_hundred', 'total_vaccinations_per_hundred',
#        'people_fully_vaccinated', 'people_vaccinated_per_hundred',
#        'daily_vaccinations', 'daily_vaccinations_per_million'],
#       dtype='object')

# %% [markdown]
# Similarly, we removed redundant columns and removed the RUCC and UIC which are only applied to counties.

# %%
state_current = mergeCovStatePovVac[['state', 'date_x', 'cases', 'deaths', 'male', 'female', 'population',
       'female_proportion', 'FIPStxt', 'Stabr', 
       'POVALL_2018', 'PCTPOVALL_2018', 'POV017_2018', 'PCTPOV017_2018',
       'MEDHHINC_2018', 'people_vaccinated', 'people_fully_vaccinated_per_hundred', 'total_vaccinations_per_hundred',
       'people_fully_vaccinated', 'people_vaccinated_per_hundred',
       'daily_vaccinations', 'daily_vaccinations_per_million']]

# %%
state_current.isnull().sum()
# Out:
# state                                  0
# date_x                                 0
# cases                                  0
# deaths                                 0
# male                                   0
# female                                 0
# population                             0
# female_proportion                      0
# FIPStxt                                0
# Stabr                                  0
# POVALL_2018                            0
# PCTPOVALL_2018                         0
# POV017_2018                            0
# PCTPOV017_2018                         0
# MEDHHINC_2018                          0
# people_vaccinated                      0
# people_fully_vaccinated_per_hundred    0
# total_vaccinations_per_hundred         0
# people_fully_vaccinated                0
# people_vaccinated_per_hundred          0
# daily_vaccinations                     0
# daily_vaccinations_per_million         0
# dtype: int64

# %% [markdown]
# There is no missing values left. It is clear for analysis and visualization.

# %% [markdown]
# ### Merge time series state-level data

# %%
mergeCovStatets = pd.merge(dfcovSt, state_pop, how='inner', on = 'state')
mergeCovStatets.head()
# Out:
#      state        date  cases  deaths     male   female  population  \
# 0  Alabama  2020-01-22      0       0  2355799  2508881     4864680
# 1  Alabama  2020-01-23      0       0  2355799  2508881     4864680
# 2  Alabama  2020-01-24      0       0  2355799  2508881     4864680
# 3  Alabama  2020-01-25      0       0  2355799  2508881     4864680
# 4  Alabama  2020-01-26      0       0  2355799  2508881     4864680
#
#    female_proportion
# 0           0.515734
# 1           0.515734
# 2           0.515734
# 3           0.515734
# 4           0.515734

# %%
mergeCovStatePovts = pd.merge(mergeCovStatets, dfPoverty, how = "inner", left_on = "state", right_on = "Area_name")
mergeCovStatePovts.head()
# Out:
#      state        date  cases  deaths     male   female  population  \
# 0  Alabama  2020-01-22      0       0  2355799  2508881     4864680
# 1  Alabama  2020-01-23      0       0  2355799  2508881     4864680
# 2  Alabama  2020-01-24      0       0  2355799  2508881     4864680
# 3  Alabama  2020-01-25      0       0  2355799  2508881     4864680
# 4  Alabama  2020-01-26      0       0  2355799  2508881     4864680
#
#    female_proportion  FIPStxt Stabr Area_name Rural-urban_Continuum_Code_2013  \
# 0           0.515734     1000    AL   Alabama                             NaN
# 1           0.515734     1000    AL   Alabama                             NaN
# 2           0.515734     1000    AL   Alabama                             NaN
# 3           0.515734     1000    AL   Alabama                             NaN
# 4           0.515734     1000    AL   Alabama                             NaN
#
#   Urban_Influence_Code_2013  POVALL_2018  PCTPOVALL_2018  POV017_2018  \
# 0                       NaN       801758            16.8       255613
# 1                       NaN       801758            16.8       255613
# 2                       NaN       801758            16.8       255613
# 3                       NaN       801758            16.8       255613
# 4                       NaN       801758            16.8       255613
#
#    PCTPOV017_2018  MEDHHINC_2018
# 0            23.9          49881
# 1            23.9          49881
# 2            23.9          49881
# 3            23.9          49881
# 4            23.9          49881

# %% [markdown]
# Here, we removed the duplicate District of Columbia as the current data.

# %%
mergeCovStatePovts.drop(mergeCovStatePovts[mergeCovStatePovts.FIPStxt == 11001].index, inplace = True)
mergeCovStatePovts.head()
# Out:
#      state        date  cases  deaths     male   female  population  \
# 0  Alabama  2020-01-22      0       0  2355799  2508881     4864680
# 1  Alabama  2020-01-23      0       0  2355799  2508881     4864680
# 2  Alabama  2020-01-24      0       0  2355799  2508881     4864680
# 3  Alabama  2020-01-25      0       0  2355799  2508881     4864680
# 4  Alabama  2020-01-26      0       0  2355799  2508881     4864680
#
#    female_proportion  FIPStxt Stabr Area_name Rural-urban_Continuum_Code_2013  \
# 0           0.515734     1000    AL   Alabama                             NaN
# 1           0.515734     1000    AL   Alabama                             NaN
# 2           0.515734     1000    AL   Alabama                             NaN
# 3           0.515734     1000    AL   Alabama                             NaN
# 4           0.515734     1000    AL   Alabama                             NaN
#
#   Urban_Influence_Code_2013  POVALL_2018  PCTPOVALL_2018  POV017_2018  \
# 0                       NaN       801758            16.8       255613
# 1                       NaN       801758            16.8       255613
# 2                       NaN       801758            16.8       255613
# 3                       NaN       801758            16.8       255613
# 4                       NaN       801758            16.8       255613
#
#    PCTPOV017_2018  MEDHHINC_2018
# 0            23.9          49881
# 1            23.9          49881
# 2            23.9          49881
# 3            23.9          49881
# 4            23.9          49881

# %% [markdown]
# Here, we applied the left join, as the date of the previous dataframe ranges from Jan 2020 to current date, while the vaccination data includes from Jan 2021. We need to keep the cases/deaths data before Jan 2021.

# %%
mergeCovStatePovVacts = pd.merge(mergeCovStatePovts, dfvac, how = "left", left_on = ["state", "date"], right_on = ["location", "date"])
mergeCovStatePovVacts
# Out:
#          state        date  cases  deaths     male   female  population  \
# 0      Alabama  2020-01-22      0       0  2355799  2508881     4864680
# 1      Alabama  2020-01-23      0       0  2355799  2508881     4864680
# 2      Alabama  2020-01-24      0       0  2355799  2508881     4864680
# 3      Alabama  2020-01-25      0       0  2355799  2508881     4864680
# 4      Alabama  2020-01-26      0       0  2355799  2508881     4864680
# ...        ...         ...    ...     ...      ...      ...         ...
# 28351  Wyoming  2021-07-26  64451     766   296979   284857      581836
# 28352  Wyoming  2021-07-27  64623     776   296979   284857      581836
# 28353  Wyoming  2021-07-28  64623     776   296979   284857      581836
# 28354  Wyoming  2021-07-29  64955     776   296979   284857      581836
# 28355  Wyoming  2021-07-30  65127     776   296979   284857      581836
#
#        female_proportion  FIPStxt Stabr  ... PCTPOV017_2018 MEDHHINC_2018  \
# 0               0.515734     1000    AL  ...           23.9         49881
# 1               0.515734     1000    AL  ...           23.9         49881
# 2               0.515734     1000    AL  ...           23.9         49881
# 3               0.515734     1000    AL  ...           23.9         49881
# 4               0.515734     1000    AL  ...           23.9         49881
# ...                  ...      ...   ...  ...            ...           ...
# 28351           0.489583    56000    WY  ...           13.1         62259
# 28352           0.489583    56000    WY  ...           13.1         62259
# 28353           0.489583    56000    WY  ...           13.1         62259
# 28354           0.489583    56000    WY  ...           13.1         62259
# 28355           0.489583    56000    WY  ...           13.1         62259
#
#       location  people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0          NaN                NaN                                  NaN
# 1          NaN                NaN                                  NaN
# 2          NaN                NaN                                  NaN
# 3          NaN                NaN                                  NaN
# 4          NaN                NaN                                  NaN
# ...        ...                ...                                  ...
# 28351  Wyoming           238306.0                                36.35
# 28352  Wyoming           238369.0                                36.36
# 28353  Wyoming           239841.0                                36.51
# 28354  Wyoming           240393.0                                36.56
# 28355  Wyoming           240961.0                                36.61
#
#        total_vaccinations_per_hundred  people_fully_vaccinated  \
# 0                                 NaN                      NaN
# 1                                 NaN                      NaN
# 2                                 NaN                      NaN
# 3                                 NaN                      NaN
# 4                                 NaN                      NaN
# ...                               ...                      ...
# 28351                           76.50                 210397.0
# 28352                           76.50                 210449.0
# 28353                           76.90                 211288.0
# 28354                           77.03                 211609.0
# 28355                           77.16                 211874.0
#
#        people_vaccinated_per_hundred daily_vaccinations  \
# 0                                NaN                NaN
# 1                                NaN                NaN
# 2                                NaN                NaN
# 3                                NaN                NaN
# 4                                NaN                NaN
# ...                              ...                ...
# 28351                          41.18              583.0
# 28352                          41.19              647.0
# 28353                          41.44              708.0
# 28354                          41.54              702.0
# 28355                          41.63              697.0
#
#        daily_vaccinations_per_million
# 0                                 NaN
# 1                                 NaN
# 2                                 NaN
# 3                                 NaN
# 4                                 NaN
# ...                               ...
# 28351                          1007.0
# 28352                          1118.0
# 28353                          1223.0
# 28354                          1213.0
# 28355                          1204.0
#
# [28356 rows x 26 columns]

# %%
mergeCovStatePovVacts.isnull().sum()
# Out:
# state                                      0
# date                                       0
# cases                                      0
# deaths                                     0
# male                                       0
# female                                     0
# population                                 0
# female_proportion                          0
# FIPStxt                                    0
# Stabr                                      0
# Area_name                                  0
# Rural-urban_Continuum_Code_2013        28356
# Urban_Influence_Code_2013              28356
# POVALL_2018                                0
# PCTPOVALL_2018                             0
# POV017_2018                                0
# PCTPOV017_2018                             0
# MEDHHINC_2018                              0
# location                               18156
# people_vaccinated                      18472
# people_fully_vaccinated_per_hundred    18524
# total_vaccinations_per_hundred         18462
# people_fully_vaccinated                18524
# people_vaccinated_per_hundred          18472
# daily_vaccinations                     18207
# daily_vaccinations_per_million         18207
# dtype: int64

# %% [markdown]
# Due to the missing values in the vaccination data, we choose to backfill the missing values to avoid potential breaks in the plots. Also, we removed redundant columns as well.

# %%
state_ts = mergeCovStatePovVacts[['state', 'date', 'cases', 'deaths', 'male', 'female', 'population',
       'female_proportion', 'FIPStxt', 'Stabr', 
       'POVALL_2018', 'PCTPOVALL_2018', 'POV017_2018', 'PCTPOV017_2018',
       'MEDHHINC_2018', 'people_vaccinated', 'people_fully_vaccinated_per_hundred', 'total_vaccinations_per_hundred',
       'people_fully_vaccinated', 'people_vaccinated_per_hundred',
       'daily_vaccinations', 'daily_vaccinations_per_million']]
state_ts.fillna(method = "bfill", inplace = True)
# Out:
# D:\anaconda3\lib\site-packages\pandas\core\frame.py:4317: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   return super().fillna(

# %%
state_ts.head()
# Out:
#      state        date  cases  deaths     male   female  population  \
# 0  Alabama  2020-01-22      0       0  2355799  2508881     4864680
# 1  Alabama  2020-01-23      0       0  2355799  2508881     4864680
# 2  Alabama  2020-01-24      0       0  2355799  2508881     4864680
# 3  Alabama  2020-01-25      0       0  2355799  2508881     4864680
# 4  Alabama  2020-01-26      0       0  2355799  2508881     4864680
#
#    female_proportion  FIPStxt Stabr  ...  POV017_2018  PCTPOV017_2018  \
# 0           0.515734     1000    AL  ...       255613            23.9
# 1           0.515734     1000    AL  ...       255613            23.9
# 2           0.515734     1000    AL  ...       255613            23.9
# 3           0.515734     1000    AL  ...       255613            23.9
# 4           0.515734     1000    AL  ...       255613            23.9
#
#    MEDHHINC_2018  people_vaccinated  people_fully_vaccinated_per_hundred  \
# 0          49881            70861.0                                 0.15
# 1          49881            70861.0                                 0.15
# 2          49881            70861.0                                 0.15
# 3          49881            70861.0                                 0.15
# 4          49881            70861.0                                 0.15
#
#    total_vaccinations_per_hundred  people_fully_vaccinated  \
# 0                            1.59                   7270.0
# 1                            1.59                   7270.0
# 2                            1.59                   7270.0
# 3                            1.59                   7270.0
# 4                            1.59                   7270.0
#
#    people_vaccinated_per_hundred  daily_vaccinations  \
# 0                           1.45              5906.0
# 1                           1.45              5906.0
# 2                           1.45              5906.0
# 3                           1.45              5906.0
# 4                           1.45              5906.0
#
#    daily_vaccinations_per_million
# 0                          1205.0
# 1                          1205.0
# 2                          1205.0
# 3                          1205.0
# 4                          1205.0
#
# [5 rows x 22 columns]

# %% [markdown]
# ## Section 3 Plot
# ### National level Cases, Deaths, Vaccination

# %% [markdown]
# First, we aggregate the state level time series data by dates to derive the national level data by date.

# %%
nation_ts = pd.DataFrame(state_ts.groupby('date')[['cases', 'deaths', 'people_fully_vaccinated', 'people_vaccinated']].sum())
nation_ts.reset_index(inplace = True)
nation_ts.fillna(method = "bfill", inplace = True)
nation_ts
# Out:
#            date     cases  deaths  people_fully_vaccinated  people_vaccinated
# 0    2020-01-22         1       1                 820494.0          7334041.0
# 1    2020-01-23         1       1                 820494.0          7334041.0
# 2    2020-01-24         2       1                 820494.0          7334041.0
# 3    2020-01-25         2       1                 820494.0          7334041.0
# 4    2020-01-26         5       1                 820494.0          7334041.0
# ..          ...       ...     ...                      ...                ...
# 551  2021-07-26  34191481  606651              159856855.0        184710975.0
# 552  2021-07-27  34261690  607100              159994251.0        184974818.0
# 553  2021-07-28  34329502  607476              160265875.0        185466924.0
# 554  2021-07-29  34406569  607796              160535336.0        185904325.0
# 555  2021-07-30  34600205  608686              160840960.0        186455723.0
#
# [556 rows x 5 columns]

# %% [markdown]
# Then we subsetted the dataframe and derive the daily cases by differentiate the cumulative data. (also we smoothed out the cases and deaths for better visualization.)

# %%
natCaseDeath = nation_ts
natCaseDeath[['cases', 'deaths', 'people_fully_vaccinated', 'people_vaccinated']] = natCaseDeath[['cases', 'deaths', 'people_fully_vaccinated', 'people_vaccinated']].rolling(7).mean()
natCaseDeath.date = pd.to_datetime(natCaseDeath.date)
natCaseDeathDay = natCaseDeath.diff()
natCaseDeathDay['date'] = natCaseDeath['date']

# %%
# %matplotlib inline

# %%
fig, ax = plt.subplots(figsize=(12,6))
plt.title("US national cumulative COVID cases, death and fully vaccinated since 2020-01-22")
sns.lineplot(data = natCaseDeath, x = "date", y = 'cases', palette="tab10", linewidth=2.5, label = 'cases')
sns.lineplot(data = natCaseDeath, x = "date", y = 'deaths', palette="tab10", linewidth=2.5, label = 'deaths')
sns.lineplot(data = natCaseDeath, x = "date", y = 'people_fully_vaccinated', palette="tab10", linewidth=2.5, label = 'people fully vaccinated')
sns.lineplot(data = natCaseDeath, x = "date", y = 'people_vaccinated', palette="tab10", linewidth=2.5, label = 'people vaccinated')
plt.grid(True)
ax.set(xlabel="Date", ylabel="Cumulative Counts")
plt.show()

# %% [markdown]
# There are big increases in cases prior to intro of vaccines. With the introduction of the vaccination, the increase in total cases slowed down.

# %%
fig, ax = plt.subplots(figsize=(12,6))
plt.title("US national daily COVID cases, deaths and fully vaccinated since 2020-01-22")
sns.lineplot(data = natCaseDeathDay, x = "date", y = 'cases', palette="tab10", linewidth=2.5, label = 'cases')
sns.lineplot(data = natCaseDeathDay, x = "date", y = 'deaths', palette="tab10", linewidth=2.5, label = 'deaths')
sns.lineplot(data = natCaseDeathDay, x = "date", y = 'people_fully_vaccinated', palette="tab10", linewidth=2.5, label = 'people fully vaccinated')
sns.lineplot(data = natCaseDeathDay, x = "date", y = 'people_vaccinated', palette="tab10", linewidth=2.5, label = 'people vaccinated')
plt.grid(True)
ax.set(xlabel="Date", ylabel="Counts")
plt.show()

# %% [markdown]
# We can see several waves by observing the increasing daily cases in April 2020, July/August 2020 and November/December 2020.
# Also, the introduction of vaccine drastically decreased daily cases after 2021.

# %%
nation_cumulative_ts = pd.DataFrame(state_ts.groupby('date')[['cases', 'deaths', 'people_fully_vaccinated', 'people_vaccinated']].sum())
nation_daily_ts = nation_cumulative_ts.diff()

# %%
state_ts.loc[:,'casePer100'] = state_ts.cases/state_ts.population*100
state_ts.loc[:,'vacPer100'] = state_ts.people_fully_vaccinated/state_ts.population*100
# Out:
# D:\anaconda3\lib\site-packages\pandas\core\indexing.py:1596: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   self.obj[key] = _infer_fill_value(value)
# D:\anaconda3\lib\site-packages\pandas\core\indexing.py:1745: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   isetter(ilocs[0], value)

# %%
state_ts_curr = state_ts[state_ts.date == "2021-07-30"]
state_ts_curr_sorted = state_ts_curr.sort_values('casePer100')
x = state_ts_curr_sorted.state
y = state_ts_curr_sorted.casePer100
z = state_ts_curr.vacPer100

my_cmap = plt.get_cmap("flag")
rescale = lambda y: (y - np.min(y)) / (np.max(y) - np.min(y))
plt.figure(figsize=(15,15))
plt.grid(True)
plt.barh(x, y, align='center', color = my_cmap(rescale(y)))
plt.xlabel('Cases per 100', fontsize = 15)
plt.title('Cases per 100 in each state 2021-07-30', fontsize = 20)

plt.show()

# %% [markdown]
# North Dakota currently has highest cases per 100 which is 5 times that of Hawaii.

# %%
state_ts_curr_sorted = state_ts_curr.sort_values('vacPer100')
x = state_ts_curr_sorted.state
y = state_ts_curr_sorted.vacPer100

my_cmap = plt.get_cmap("flag")
rescale = lambda y: (y - np.min(y)) / (np.max(y) - np.min(y))
plt.figure(figsize=(15,15))
plt.grid(True)
plt.barh(x, y, align='center', color = my_cmap(rescale(y)))
plt.xlabel('Fully Vaccinated per 100', fontsize = 15)
plt.title('Fully Vaccinated per 100 in each state 2021-07-30', fontsize = 20)

plt.show()

# %% [markdown]
# North-Eastern Us has relatively higher proportion of residents fully vaccinated.

# %%
county_current.loc[:,'cases100'] = county_current.loc[:,"cases"]/county_current.loc[:,"population"]*100
county_current.loc[:,'deaths100'] = county_current.loc[:,"deaths"]/county_current.loc[:,"population"]*100
county_current.loc[:,'deathratio'] = county_current.loc[:,"deaths"]/county_current.loc[:,"cases"]

# %%
Metro = {"Level 1": "Metro", 
         "Level 2": "Metro",
         "Level 3": "Metro",
         "Level 4": "Adjacent to Metro",
         "Level 5": "Not adjacent to metro",
         "Level 6": "Adjacent to Metro", 
         "Level 7": "Not adjacent to metro",
         "Level 8": "Adjacent to Metro",
         "Level 9": "Not adjacent to metro"
          }

county_current["Metro"] = county_current["Rural-urban_Continuum_Code_2013"].map(Metro)

# %%
plt.figure(figsize=(12,10))
plt.title("Plot of Median Household Income vs COVID Deaths (per 100) at county level", fontsize = 15)
plt.xlabel("Median Household Income", fontsize = 15)
plt.ylabel("COVID Deaths (per 100)", fontsize = 15)
plt.grid(True)
colors = {'Metro':'k', 'Adjacent to Metro':'c', 'Not adjacent to metro':'r'}
groups = county_current.groupby('Metro')
for name, group in groups:
    plt.plot(group.MEDHHINC_2018, group.deaths100, color = colors[name], marker='o', linestyle='', markersize=5, label=name, alpha = 0.5)
    plt.plot(group.MEDHHINC_2018, np.poly1d(np.polyfit(group.MEDHHINC_2018, group.deaths100, 1))(group.MEDHHINC_2018), 
             color = colors[name], alpha = 1, linewidth=3)
    plt.legend(fontsize=16)
plt.show()

# %% [markdown]
# Counties with lower median household income may have less sophisticated medical facilities.

# %%
statelonlat = pd.read_csv('data/StateLonLat.csv')
statelonlat.head()

# %%
mergeCovState2 = pd.merge(state_ts, statelonlat, how='left', on = 'state')
mergeCovState2['deathPer100'] = mergeCovState2.deaths/mergeCovState2.population*100

# %%
mergeCovState2["daylastdigit"] = mergeCovState2['date'].apply(lambda x: (x[-1] == "0")|(x[-1] == "5"))
mergeCovState5days = mergeCovState2[mergeCovState2["daylastdigit"]]
mergeCovState5days.head()

# %%
mergeCovState5days.columns

# %%
fig = px.scatter_geo(mergeCovState10days, lon = "longitude", lat = "latitude", hover_name='state', size="casePer100",
               animation_frame="date", projection='albers usa')
fig.show()

# %%
fig = px.scatter_geo(mergeCovState10days, lon = "longitude", lat = "latitude", hover_name='state', size="deathPer100",
               animation_frame="date", projection='albers usa')
fig.show()

# %%
county_ts["daylastdigit"] = county_ts['date'].apply(lambda x: (x[-1] == "0") | (x[-1] == "5") )
county_ts['casePer100'] = county_ts.cases/county_ts.population*100
county_ts['deathPer100'] = county_ts.deaths/county_ts.population*100
county_ts5days = county_ts[county_ts["daylastdigit"]]
county_ts5days.head()

# %%
fig = px.scatter_geo(county_ts5days, lon = "long_x", lat = "lat_x", hover_name='county_x', size="casePer100",
               animation_frame="date", projection='albers usa', color = "Rural-urban_Continuum_Code_2013")
fig.update_layout(
    legend=dict(
        traceorder="reversed",
        title_font_family="Times New Roman",
        font=dict(
            family="Courier",
            size=9,
            color="black"
        ),
        bgcolor="LightSteelBlue",
        bordercolor="Black",
        borderwidth=2
    )
)
fig.show()

# %% [markdown]
# Pandemic first breakout in metro areas on the Eastern and southern part of US. Then, it starts spreading to non-metro areas.

# %%
fig = px.scatter_geo(county_ts5days, lon = "long_x", lat = "lat_x", hover_name='county_x', size="deathPer100",
               animation_frame="date", projection='albers usa', color = "Rural-urban_Continuum_Code_2013")
fig.update_layout(
    legend=dict(
        traceorder="reversed",
        title_font_family="Times New Roman",
        font=dict(
            family="Courier",
            size=9,
            color="black"
        ),
        bgcolor="LightSteelBlue",
        bordercolor="Black",
        borderwidth=2
    )
)
fig.show()
